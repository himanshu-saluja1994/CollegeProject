# %%
import os
import csv
from operator import itemgetter
from collections import Counter
from prettytable import PrettyTable

# XXX: Place your "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings at the following
# location: resources/ch03-linkedin/my_connections.csv

CSV_FILE = os.path.join('connections.csv')

transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO."
# Other variations could be handled as well, such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Job Title'].split('/')
                  if contact['Job Title'].strip() != ''])

# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print ""

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 2]
print ""

print pt
# Out:
# +---------------+------+
# | Token         | Freq |
# +---------------+------+
# | Software      | 64   |
# | Engineer      | 50   |
# | Student       | 43   |
# | Developer     | 24   |
# | Manager       | 11   |
# | Intern        | 10   |
# | Assistant     | 7    |
# | Technical     | 7    |
# | Ambassador    | 6    |
# | Placement     | 6    |
# | Member        | 6    |
# | Senior        | 5    |
# | and           | 5    |
# | Associate     | 5    |
# | Analyst       | 4    |
# | Coordinator   | 4    |
# | Professor     | 4    |
# | Head          | 3    |
# | Founder       | 3    |
# | Technology    | 3    |
# | Staff         | 3    |
# | Engineering   | 3    |
# | Training      | 3    |
# | Consultant    | 3    |
# | Web           | 2    |
# | Recruiter     | 2    |
# | Test          | 2    |
# | Business      | 2    |
# | Director      | 2    |
# | Officer       | 2    |
# | Team          | 2    |
# | Designer      | 2    |
# | Firefox       | 2    |
# | Human         | 2    |
# | Campus        | 2    |
# | Cell          | 2    |
# | engineer      | 2    |
# | Data          | 2    |
# | Administrator | 2    |
# | Executive     | 2    |
# | Product       | 2    |
# | Programmer    | 2    |
# +---------------+------+

# %%
import os
import csv
from collections import Counter
from operator import itemgetter
from prettytable import PrettyTable

# XXX: Place your "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings at the following
# location: resources/ch03-linkedin/my_connections.csv

CSV_FILE = os.path.join('connections.csv')

# Define a set of transforms that converts the first item
# to the second item. Here, we're simply handling some
# commonly known abbreviations, stripping off common suffixes, 
# etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)
[pt.add_row([company, freq]) 
 for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print pt
# Out:
# +----------------------------------------------------------------------------------+------+
# | Company                                                                          | Freq |
# +----------------------------------------------------------------------------------+------+
# | Indian Institute of Information Technology, Allahabad, India                     | 14   |
# | IIIT Allahabad                                                                   | 12   |
# | Amazon                                                                           | 6    |
# | Mozilla                                                                          | 6    |
# | IIIT ALLAHABAD                                                                   | 5    |
# | Juniper Networks                                                                 | 4    |
# | Flipkart.com                                                                     | 4    |
# | MAQ Software                                                                     | 3    |
# | Indian Institute of Information Technology, Allahabad                            | 3    |
# | Snapdeal                                                                         | 3    |
# | HT Media Ltd                                                                     | 3    |
# | Directi                                                                          | 3    |
# | InnoPark(India) Pvt.Ltd                                                          | 2    |
# | Adobe                                                                            | 2    |
# | IIITA                                                                            | 2    |
# | Amazon.com                                                                       | 2    |
# | Wikimedia Foundation                                                             | 2    |
# | Morgan Stanley                                                                   | 2    |
# | Mahindra Comviva                                                                 | 2    |
# | Techical Society of Indian Institute of Information Technology, Allahabad, India | 2    |
# | hike messenger                                                                   | 2    |
# | Goibibo                                                                          | 2    |
# | SAP                                                                              | 2    |
# | Citi                                                                             | 2    |
# | TomTom                                                                           | 2    |
# +----------------------------------------------------------------------------------+------+

# %%
import os
import csv
import random
import json
import operator
from nltk.metrics.distance import jaccard_distance
from cluster import HierarchicalClustering

CSV_FILE = os.path.join('connections.csv')

OUT_FILE = 'viz/d6-data.json'


DISTANCE_THRESHOLD = 0.6
DISTANCE = jaccard_distance


SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        print titles
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    print ('%s %s')%(title,title)
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]
  # print clusters
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s '
                            % (contact['First Name'], contact['Last Name'] ))

    return clustered_contacts

def display_output(clustered_contacts):
    
    for titles in clustered_contacts:
        common_titles_heading = 'Common Titles: ' + ', '.join(titles)
       # print common_titles_heading
     #   print '\n'
      #  print titles
        ll=[]
        d=dict()
        for term_sep in titles:
         #   print term_sep
            sp_sep_ti=term_sep.split()
        #    print sp_sep_ti
            for sl in sp_sep_ti:
                if sl in d:
                    d[sl]=d[sl]+1
                else:
                    d[sl]=1;
            #ll.append(sl)
    #    print d
        for key in d:
            #  print d[key]
            if (d[key] * 2) >= (len(d)):
                print key
	#print max(d, key=d.get)
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
           + ', '.join(descriptive_terms)
        print descriptive_terms_heading
        print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
        print '\n'.join(clustered_contacts[titles])
        print

def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = set(titles[0].split())
        #print descriptive_terms
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        ll=[]
        d=dict()
        
        for term_sep in titles:
         #   print term_sep
            sp_sep_ti=term_sep.split()
        #    print sp_sep_ti
            for sl in sp_sep_ti:
                if sl in d:
                    d[sl]=d[sl]+1
                else:
                    d[sl]=1;
            #ll.append(sl)
        print d
        a=[]
        for key in d:
            #  print d[key]
            if (d[key] ) >= (len(titles)/2):
  #              print key
                a.append(key)
                
        print a
        print descriptive_terms

        json_output['children'].append({'name' : ', '.join(a), 
                                    'children' : [ {'name' : c.decode('utf-8', 'replace')} for c in clustered_contacts[titles] ] } )
    
        f = open(OUT_FILE, 'w')
        f.write(json.dumps(json_output, indent=1))
        f.close()
    
clustered_contacts = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts)
write_d3_json_output(clustered_contacts)
# Out:
# ['Student']
# ['Assistant Professor']
# ['Assistant Developer']
# ['Student']
# ['Student Ambassador']
# ['Software Developer']
# ['Head, Technical Affairs-Software']
# ['Student']
# ['Student']
# ['Student']
# ['Sofware Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Human Resources']
# ['Student']
# ['Student']
# ['Firefox Student Ambassador']
# ['Placement Coordinator']
# ['Filmmaker/Writer']
# Filmmaker/Writer Filmmaker/Writer
# ['Data Developer']
# ['Software Developmer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Co-founder']
# ['Assistant Manager']
# ['Software Developer']
# ['Design Secretary']
# ['Student']
# ['Telesales Executive']
# ['Management Trainee - Operations']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Developer']
# ['Oracle Database Administrator']
# ['Key Account Manager']
# ['Engineering Manager']
# ['Software Developer']
# ['Software Developer']
# ['Talent Acquisition Manager']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Student']
# ['Wireless Protocol Test Intern']
# ['Software Developer']
# ['HR Executive']
# ['Student']
# ['IT Company']
# ['Student']
# ['IT Consultant']
# ['Student']
# ['Student Ambassador']
# ['Business Development Manager']
# ['Student']
# ['Member of Technical Staff']
# ['Software Engineer']
# ['Web Designer']
# ['ECE Student']
# ['Software Developer']
# ['Intern']
# ['Intern']
# ['Head of Growth']
# ['Software Engineer']
# ['SA']
# ['Manager (Technology)']
# ['Systems Engineer']
# ['Technical Team Member']
# ['Assistant Professor']
# ['Business Developer']
# ['Software Engineer']
# ['system engineer']
# ['Software Engineer']
# ['Infrastructure Developer']
# ['Software Engineer']
# ['Engineer']
# ['Member']
# ['Software Developer']
# ['Software Engineer']
# ['Black Belt - Quality - Strategic Initiatives - Global']
# ['Firefox Student Ambassador']
# ['Student']
# ['Overall Placement Coordinator']
# ['Student']
# ['IT Consultant']
# ['IIITA Allahabad']
# ['Assistant Manager']
# ['HR - Product & Technology']
# HR - Product & Technology HR - Product & Technology
# ['Mechanical Engineer']
# ['Software Engineer']
# ['Consultant']
# ['Student Ambassador']
# ['Student']
# ['Founder & CTO']
# Founder & CTO Founder & CTO
# ['Intern']
# ['Software Developer']
# ['Student Technical Assistant']
# ['Software Developer']
# ['Data Analyst']
# ['IT Engineer']
# ['Service Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Head of Sales and Customer Engagement']
# Head of Sales and Customer Engagement Head of Sales and Customer Engagement
# ['Associate']
# ['Founder']
# ['Software Engineer']
# ['Software Engineer']
# ['Intern']
# ['Associate Manager, Corporate and Media Relations']
# Associate Manager, Corporate and Media Relations Associate Manager, Corporate and Media Relations
# ['Developer']
# ['Software Engineer']
# ['Intern']
# ['Student']
# ['Placement Coordinator']
# ['Member of Technical Staff ']
# ['Intern']
# ['Director - Software Engineering']
# ['Training Associate']
# ['Training and Placement Cell Co-ordinator']
# Training and Placement Cell Co-ordinator Training and Placement Cell Co-ordinator
# ['Internal Affairs Officer']
# ['Software developer']
# ['Developer']
# ['Research Scholar']
# ['Software Developer']
# ['Technical Team Member']
# ['Senior Director - Test Engineering']
# ['Student']
# ['Student']
# ['Senior Software Engineer']
# ['Student']
# ['Web Designer and Programmer']
# Web Designer and Programmer Web Designer and Programmer
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Professor']
# ['Software Engineer']
# ['Human Performance']
# ['Analyst']
# ['Placement Cell']
# ['Campus Recruiter']
# ['Training & Consulting in Predictive Analytics & Information Security (www.praisia.com)']
# Training & Consulting in Predictive Analytics & Information Security (www.praisia.com) Training & Consulting in Predictive Analytics & Information Security (www.praisia.com)
# ['Member of Technical Staff']
# ['Software Engineer']
# ['Founder']
# ['Sr. Software Engineer']
# ['Senior Trainer']
# ['Intern']
# ['Software Engineer']
# ['Assistant Manager']
# ['Programmer Analyst']
# ['Campus Ambassador']
# ['Tutor']
# ['Student and Placement Coordinator']
# Student and Placement Coordinator Student and Placement Coordinator
# ['Software Engineer']
# ['Intern']
# ['Graphic Engineer']
# ['Product Manager']
# ['Regional Marketing Ambassdor']
# ['Software Engineer']
# ['Student']
# ['System Analyst & Network Administrator']
# System Analyst & Network Administrator System Analyst & Network Administrator
# ['Associate Technology L1']
# ['Software Developer']
# ['Intern']
# ['Software Developer']
# ['Outreach Program for Women']
# ['Senior Software Developer']
# ['Manager']
# ['HR Recruiter']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['technical support engineer']
# ['Student']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Associate Professor']
# Manager
# Descriptive Terms: Manager
# -----------------------------------------------------------------------------------------------------
# GAURAV BANSAL
# Nishant Tiwari
# Vijay Mendiratta
# Diwas Sharma
# Dheeraj Singh
# shaloo singh
# Nasiruddin Ahmad
#
# Professor
# Training
# Associate
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------
# Monark Bag
# sanjai singh
# nipun lall
# Siri Jakka
# Adhishwar Mittal
# Samudrala Kumar
# Praisia Technologies
# Jag Rawat
#
# Technical
# Member
# Descriptive Terms: Technical, Member
# -------------------------------------------------------------------------------------------
# Aman Sinha
# Naval Kishor Meena
# Prakhar Agrawal
# Ankur Tyagi
# Abhinav Vishwa
#
# Programmer
# Analyst
# Descriptive Terms:
# ------------------------------------------------------------------------------------
# anuraag deekonda
# JP Godara
# Abhinav Gupta
# Ramanan Ramesh
# Mithilesh Kr. Mishra
#
# Consultant
# IT
# Descriptive Terms: Consultant
# ----------------------------------------
# Pradeep Mishra
# raja agarwal
# ASHISH KUMAR SAHU
#
# Cell
# Placement
# Descriptive Terms: Cell, Placement
# ----------------------------------------------------------
# Adhishwar Mittal
# divya porwal
#
# Ambassador
# Student
# Descriptive Terms: Student
# -----------------------------------------------------------------------------------
# Manu Saxena
# Abhimanyu Singh
# Harshit Gupta
# Monica Singh
# ravinder naik azmeera
# Jyoti Singh
# Vishal Srivastava
# Aman Agarwal
# Jai Mishra
# Upendra gupta
# Charul Agrawal
# Shivlal Dhundhwal
# Amarnath kumar
# Nishtha Rai
# Vikhyat Tandon
# Shubham Tyagi
# siyaram malav
# manish kumar
# Vishnu Ks
# Sumit Kumar
# Amit Kumar Singh
# Sunil Rana
# Shailendra Pratap Singh
# Ashutosh Gupta
# Ravi Kiran JP
# Deepak kumhar
# GAURAV VERMA
# Rishabh Chandel
# Navaz Mannan
# Sidharth Singla
# Talha Khan
# ANUJ SHARMA
# Ashok Danga
# Pramiti Goel
# Namrata singh chauhan
# Aaquib Khwaja
# Shreya Singh
# Pretty Meena
# Shiv Shankar Verma
# amanraj varshney
# Aman Aggarwal
# Divanshu Garg
#
# Descriptive Terms: Director, Engineering, -
# ----------------------------------------------------------------------------------
# Sriram Subramanian
# Prashanth Ashwathnarayan
#
# Developer
# Engineer
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Lakshya Goel
# Sushil Kumar
# koganti rakesh
# Aviral Sahai
# sarthak mall
# Udit Agarwal
# deepak irukula
# Sunil Kumar
# Tejaswi Reddy
# Prabhat Kumar
# Rahul Sharma
# Harsh Lalwani
# seshank koganti
# Sapan Diwakar
# Viswash Pratap Singh
# Mayank Tuteja
# Sandeep Goyal
# Ruben Roy
# Naveen Bandlamoodi
# Anoop Mishra
# Ankit Paharia
# Pritam Kumar
# Prateek Khandelwal
# Amar deep gupta
# Ankit Gupta
# Hemant Pawar
# shailesh kumar
# Rohit Wadhwa
# srikanth br
# Ajit Abhipallav
# Dinesh Pathak
# smit hinsu
# Arpit Mittal
# Adity Khandaalkar
# Abhishek Jha
# Krishna Murthy P.V.N.S.S
# Sidharth Guglani
# Aman Mamgain
# akshay khare
# Vinay Kumar
# Sumit Kumar Satnalika
# praveen kumar
# Abhishek Kumar
# Mragank Tolwani
# Aman Agarwal
# sumit gaur
# Lalit Pathak
# Shubham Jain
# Vedavyas Chigurupati
# Mayank Gupta
# Suyash Agarwal
# Aman Singh
# Akhil Yadav
# Avinash Kumar Chaudhary
# Navneet Sinha
# manish aswani
# Naveen Shukla
# Sharath Naik
# Chandresh Bhardwaj
# Vamsi Krishna
# Digvijay Singh
# Amit Meena
# Jayendra Singh
# Monika Agrawal
# Keshav Maheshwari
# vidyashankar sahu
# Akshay Gupta
# Gaurav Kaushik
# Saurabh Singh
# Mohit Kumar Lal
# Ashish Sinha
# Mohit Bansal
# Amrit Jangid
# Naveen Chalasani
#
# Placement
# Coordinator
# Descriptive Terms: Coordinator, Placement
# -------------------------------------------------------------------
# Vijendra Singh Aswal
# Placement Office IIIT Allahabad
# Shubham Kesarwani
# Aaquib Khwaja
#
# of
# Head
# Descriptive Terms: of, Head
# --------------------------------------------
# Pathik Shah
# Raj Medepalli
#
# {'Assistant': 1, 'Engineering': 1, '(Technology)': 1, 'Manager': 5, 'Product': 1}
# ['Manager']
# set(['Manager'])
# {'Assistant': 1, 'Professor': 3, 'Training': 2, 'Associate': 3}
# ['Professor', 'Associate']
# set([])
# {'Technical': 3, 'Member': 3, 'Staff': 2, 'of': 2, 'Team': 1}
# ['Technical', 'Member', 'Staff', 'of', 'Team']
# set(['Technical', 'Member'])
# {'Programmer': 2, 'Data': 1, 'System': 1, 'Analyst': 4}
# ['Programmer', 'Analyst']
# set([])
# {'Consultant': 2, 'IT': 1}
# ['Consultant', 'IT']
# set(['Consultant'])
# {'Cell': 2, 'Co-ordinator': 1, 'Placement': 2}
# ['Cell', 'Co-ordinator', 'Placement']
# set(['Cell', 'Placement'])
# {'Ambassador': 2, 'ECE': 1, 'Firefox': 1, 'Student': 4}
# ['Ambassador', 'Student']
# set(['Student'])
# {'-': 2, 'Director': 2, 'Engineering': 2, 'Test': 1, 'Senior': 1, 'Software': 1}
# ['-', 'Director', 'Engineering', 'Test', 'Senior', 'Software']
# set(['Director', 'Engineering', '-'])
# {'Graphic': 1, 'Sofware': 1, 'Business': 1, 'Service': 1, 'Assistant': 1, 'IT': 1, 'Software': 4, 'Infrastructure': 1, 'Systems': 1, 'Mechanical': 1, 'Senior': 2, 'Developer': 7, 'Data': 1, 'Engineer': 9}
# ['Engineer']
# set([])
# {'Placement': 2, 'Overall': 1, 'Coordinator': 2}
# ['Placement', 'Overall', 'Coordinator']
# set(['Coordinator', 'Placement'])
# {'of': 2, 'Head': 2, 'Growth': 1, 'Sales': 1}
# ['of', 'Head', 'Growth', 'Sales']
# set(['of', 'Head'])

# %%
import os
import csv
import random
import json
import operator
from nltk.metrics.distance import masi_distance
from cluster import HierarchicalClustering

CSV_FILE = os.path.join('connections.csv')

OUT_FILE = 'viz/d7-data.json'


DISTANCE_THRESHOLD = 0.67
DISTANCE = masi_distance


SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]
  # print clusters
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s '
                            % (contact['First Name'], contact['Last Name'] ))

    return clustered_contacts

def display_output(clustered_contacts):
    
    for titles in clustered_contacts:
        common_titles_heading = 'Common Titles: ' + ', '.join(titles)
       # print common_titles_heading
     #   print '\n'
      #  print titles
        ll=[]
        d=dict()
        for term_sep in titles:
         #   print term_sep
            sp_sep_ti=term_sep.split()
        #    print sp_sep_ti
            for sl in sp_sep_ti:
                if sl in d:
                    d[sl]=d[sl]+1
                else:
                    d[sl]=1;
            #ll.append(sl)
    #    print d
        for key in d:
            #  print d[key]
            if (d[key] * 2) >= (len(d)):
                print key
	#print max(d, key=d.get)
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
           + ', '.join(descriptive_terms)
        print descriptive_terms_heading
        print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
        print '\n'.join(clustered_contacts[titles])
        print

def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = set(titles[0].split())
        #print descriptive_terms
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        ll=[]
        d=dict()
        
        for term_sep in titles:
         #   print term_sep
            sp_sep_ti=term_sep.split()
        #    print sp_sep_ti
            for sl in sp_sep_ti:
                if sl in d:
                    d[sl]=d[sl]+1
                else:
                    d[sl]=1;
            #ll.append(sl)
        print d
        a=[]
        for key in d:
            #  print d[key]
            if (d[key] ) >= (len(titles)/2):
  #              print key
                a.append(key)
                
        print a
        print descriptive_terms

        json_output['children'].append({'name' : ', '.join(a), 
                                    'children' : [ {'name' : c.decode('utf-8', 'replace')} for c in clustered_contacts[titles] ] } )
    
        f = open(OUT_FILE, 'w')
        f.write(json.dumps(json_output, indent=1))
        f.close()
    
clustered_contacts = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts)
write_d3_json_output(clustered_contacts)
# Out:
# Manager
# Descriptive Terms: Manager
# -----------------------------------------------------------------------------------------------------
# GAURAV BANSAL
# Nishant Tiwari
# Vijay Mendiratta
# Diwas Sharma
# Dheeraj Singh
# shaloo singh
# Nasiruddin Ahmad
#
# Professor
# Training
# Associate
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------
# Monark Bag
# sanjai singh
# nipun lall
# Siri Jakka
# Adhishwar Mittal
# Samudrala Kumar
# Praisia Technologies
# Jag Rawat
#
# Developer
# Descriptive Terms: Developer
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Lakshya Goel
# Sushil Kumar
# Prabhat Kumar
# seshank koganti
# Viswash Pratap Singh
# Ruben Roy
# Naveen Bandlamoodi
# Anoop Mishra
# Pritam Kumar
# Amar deep gupta
# Hemant Pawar
# srikanth br
# smit hinsu
# Abhishek Jha
# akshay khare
# Vinay Kumar
# Abhishek Kumar
# Aman Agarwal
# Vedavyas Chigurupati
# Suyash Agarwal
# Aman Singh
# Saurabh Singh
# Mohit Kumar Lal
# Ashish Sinha
#
# Programmer
# Analyst
# Descriptive Terms:
# ------------------------------------------------------------------------------------
# anuraag deekonda
# JP Godara
# Abhinav Gupta
# Ramanan Ramesh
# Mithilesh Kr. Mishra
#
# Consultant
# IT
# Descriptive Terms: Consultant
# ----------------------------------------
# Pradeep Mishra
# raja agarwal
# ASHISH KUMAR SAHU
#
# Cell
# Placement
# Descriptive Terms: Cell, Placement
# ----------------------------------------------------------
# Adhishwar Mittal
# divya porwal
#
# Ambassador
# Student
# Descriptive Terms: Student
# -----------------------------------------------------------------------------------
# Manu Saxena
# Abhimanyu Singh
# Harshit Gupta
# Monica Singh
# ravinder naik azmeera
# Jyoti Singh
# Vishal Srivastava
# Aman Agarwal
# Jai Mishra
# Upendra gupta
# Charul Agrawal
# Shivlal Dhundhwal
# Amarnath kumar
# Nishtha Rai
# Vikhyat Tandon
# Shubham Tyagi
# siyaram malav
# manish kumar
# Vishnu Ks
# Sumit Kumar
# Amit Kumar Singh
# Sunil Rana
# Shailendra Pratap Singh
# Ashutosh Gupta
# Ravi Kiran JP
# Deepak kumhar
# GAURAV VERMA
# Rishabh Chandel
# Navaz Mannan
# Sidharth Singla
# Talha Khan
# ANUJ SHARMA
# Ashok Danga
# Pramiti Goel
# Namrata singh chauhan
# Aaquib Khwaja
# Shreya Singh
# Pretty Meena
# Shiv Shankar Verma
# amanraj varshney
# Aman Aggarwal
# Divanshu Garg
#
# Member
# of
# Technical
# Staff
# Descriptive Terms: Member, of, Technical, Staff
# --------------------------------------------------------------------
# Aman Sinha
# Prakhar Agrawal
# Abhinav Vishwa
#
# Engineer
# Descriptive Terms: Engineer
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# koganti rakesh
# Aviral Sahai
# sarthak mall
# Udit Agarwal
# deepak irukula
# Sunil Kumar
# Tejaswi Reddy
# Rahul Sharma
# Harsh Lalwani
# Sapan Diwakar
# Mayank Tuteja
# Sandeep Goyal
# Ankit Paharia
# Prateek Khandelwal
# Ankit Gupta
# shailesh kumar
# Rohit Wadhwa
# Ajit Abhipallav
# Dinesh Pathak
# Arpit Mittal
# Adity Khandaalkar
# Krishna Murthy P.V.N.S.S
# Sidharth Guglani
# Aman Mamgain
# Sumit Kumar Satnalika
# praveen kumar
# Mragank Tolwani
# sumit gaur
# Lalit Pathak
# Shubham Jain
# Mayank Gupta
# Akhil Yadav
# Avinash Kumar Chaudhary
# Navneet Sinha
# manish aswani
# Naveen Shukla
# Sharath Naik
# Chandresh Bhardwaj
# Vamsi Krishna
# Digvijay Singh
# Amit Meena
# Jayendra Singh
# Monika Agrawal
# Keshav Maheshwari
# vidyashankar sahu
# Akshay Gupta
# Gaurav Kaushik
# Mohit Bansal
# Amrit Jangid
# Naveen Chalasani
#
# Placement
# Coordinator
# Descriptive Terms: Coordinator, Placement
# -------------------------------------------------------------------
# Vijendra Singh Aswal
# Placement Office IIIT Allahabad
# Shubham Kesarwani
# Aaquib Khwaja
#
# {'Assistant': 1, 'Engineering': 1, '(Technology)': 1, 'Manager': 5, 'Product': 1}
# ['Manager']
# set(['Manager'])
# {'Assistant': 1, 'Professor': 3, 'Training': 2, 'Associate': 3}
# ['Professor', 'Associate']
# set([])
# {'Infrastructure': 1, 'Business': 1, 'Assistant': 1, 'Senior': 1, 'Software': 2, 'Data': 1, 'Developer': 7}
# ['Developer']
# set(['Developer'])
# {'Programmer': 2, 'Data': 1, 'System': 1, 'Analyst': 4}
# ['Programmer', 'Analyst']
# set([])
# {'Consultant': 2, 'IT': 1}
# ['Consultant', 'IT']
# set(['Consultant'])
# {'Cell': 2, 'Co-ordinator': 1, 'Placement': 2}
# ['Cell', 'Co-ordinator', 'Placement']
# set(['Cell', 'Placement'])
# {'Ambassador': 2, 'ECE': 1, 'Firefox': 1, 'Student': 4}
# ['Ambassador', 'Student']
# set(['Student'])
# {'Member': 2, 'of': 2, 'Technical': 2, 'Staff': 2}
# ['Member', 'of', 'Technical', 'Staff']
# set(['Member', 'of', 'Technical', 'Staff'])
# {'Graphic': 1, 'Sofware': 1, 'Service': 1, 'IT': 1, 'Systems': 1, 'Mechanical': 1, 'Senior': 1, 'Software': 2, 'Engineer': 9}
# ['Engineer']
# set(['Engineer'])
# {'Placement': 2, 'Overall': 1, 'Coordinator': 2}
# ['Placement', 'Overall', 'Coordinator']
# set(['Coordinator', 'Placement'])

# %%
import os
import csv
import random
import json
import operator
from nltk.metrics.distance import edit_distance
from cluster import HierarchicalClustering

CSV_FILE = os.path.join('connections.csv')

OUT_FILE = 'viz/d8-data.json'


DISTANCE_THRESHOLD = 4
DISTANCE = edit_distance


SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):


    def score(title1, title2): 

        return DISTANCE((title1), (title2))
    all_titles=[]
    all_titles.append("Student")
    all_titles.append("Assistant Professor")
    all_titles.append("Student Ambassador")
    all_titles.append("Assistant Developer")
    all_titles.append("Human Resources")
    all_titles.append("Software Developer")
    all_titles.append("Head, Technical Affairs-Software")
    all_titles.append("Sofware Engineer")

    all_titles.append("Software Engineer")
    all_titles.append("Design Secretary")
    all_titles.append("Telesales Executive")
    all_titles.append("Filmmaker")
    all_titles.append("Writer")
    all_titles.append("Data Developer")
    all_titles.append("Software Developmer")
    all_titles.append("Co-founder")

    all_titles.append("Assistant Manager")
    
    all_titles.append("Management Trainee - Operations")
    all_titles.append("Oracle Database Administrator")
    all_titles.append("Key Account Manager")
    all_titles.append("Engineering Manager")
    all_titles.append("Talent Acquisition Manager")
    all_titles.append("Wireless Protocol Test Intern")

    all_titles.append("HR Executive")
    all_titles.append("IT Company")
    all_titles.append("Business Development Manager")
    all_titles.append("Member of Technical Staff")
    all_titles.append("Web Designer")
    all_titles.append("ECE Student")
    all_titles.append("Intern")
    all_titles.append("Head of Growth")

    all_titles.append("SA")
    all_titles.append("Manager (Technology)")
    all_titles.append("Systems Engineer")
    all_titles.append("Technical Team Member")
    all_titles.append("Business Developer")
    all_titles.append("system engineer")
    all_titles.append("Infrastructure Developer")
    all_titles.append("Engineer")
    all_titles.append("Mechanical Engineer")
    all_titles.append("Student Technical Assistant")
    all_titles.append("Senior Software Engineer")
    all_titles.append("Senior Software Developer")
    all_titles.append("Associate Professor")
    all_titles.append("Professor")
    all_titles.append("Software developer")
    all_titles.append("Director - Software Engineering")
    all_titles.append("Product Manager")






    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)
    print clusters

    score_matrix=[]
    min_d=1000000
    for title1 in all_titles:
	temp=[]
	for title2 in all_titles:
	    li1=title1.split(",")
	    li2=title2.split(",")
	    for ll1 in li1:
		min_d=100000
		for ll2 in li2:
		  #  print ll1,ll2
		    d=score(ll1,ll2)
		   # print d
		    min_d=min(min_d,d)
		#print "done"
	    
    	 #   print d
	    temp.append(min_d)
	score_matrix.append(temp);
  #  print score_matrix
    print len(all_titles)

     
    i=j=k=l=0
    mini=10000
    for l1 in score_matrix:
	j=0;
	for l2 in l1:
	    if l2 < mini and i!=j:
	        mini=l2
		k=i
		l=j
	    j=j+1
	i=i+1
#    print "%d %d",(k,l)
#    print mini
    clusters = [c for c in clusters if len(c) > 1]
  # print clusters
    # Round up contacts who are in these clusters and group them together
    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s '
                            % (contact['First Name'], contact['Last Name'] ))

    return clustered_contacts

   
def display_output(clustered_contacts):
    
    for titles in clustered_contacts:
        common_titles_heading = 'Common Titles: ' + ', '.join(titles)
       # print common_titles_heading
     #   print '\n'
      #  print titles
        ll=[]
        d=dict()
        for term_sep in titles:
         #   print term_sep
            sp_sep_ti=term_sep.split()
        #    print sp_sep_ti
            for sl in sp_sep_ti:
                if sl in d:
                    d[sl]=d[sl]+1
                else:
                    d[sl]=1;
            #ll.append(sl)
    #    print d
        for key in d:
            #  print d[key]
            if (d[key] * 2) >= (len(d)):
                print key
	#print max(d, key=d.get)
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
           + ', '.join(descriptive_terms)
        print descriptive_terms_heading
        print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
        print '\n'.join(clustered_contacts[titles])
        print

def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = set(titles[0].split())
        #print descriptive_terms
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        ll=[]
        d=dict()
        
        for term_sep in titles:
         #   print term_sep
            sp_sep_ti=term_sep.split()
        #    print sp_sep_ti
            for sl in sp_sep_ti:
                if sl in d:
                    d[sl]=d[sl]+1
                else:
                    d[sl]=1;
            #ll.append(sl)
        print d
        a=[]
        for key in d:
            #  print d[key]
            if (d[key] ) >= (len(titles)/2):
  #              print key
                a.append(key)
                
        print a
        print descriptive_terms

        json_output['children'].append({'name' : ', '.join(a), 
                                    'children' : [ {'name' : c.decode('utf-8', 'replace')} for c in clustered_contacts[titles] ] } )
    
        f = open(OUT_FILE, 'w')
        f.write(json.dumps(json_output, indent=1))
        f.close()
    
clustered_contacts = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts)
write_d3_json_output(clustered_contacts)
# Out:
# [['Management Trainee - Operations'], ['Wireless Protocol Test Intern'], ['Oracle Database Administrator'], ['Head, Technical Affairs-Software'], ['Manager (Technology)'], ['Talent Acquisition Manager'], ['Head of Growth'], ['Design Secretary'], ['Human Resources'], ['Student Ambassador'], ['Telesales Executive'], ['HR Executive'], ['Director - Software Engineering'], ['Infrastructure Developer'], ['Technical Team Member'], ['Business Development Manager'], ['Mechanical Engineer'], ['Engineering Manager'], ['Key Account Manager'], ['Web Designer'], ['IT Company'], ['Co-founder'], ['Filmmaker'], ['SA'], ['Student', 'ECE Student'], ['Professor'], ['Engineer'], ['Writer', 'Intern'], ['Assistant Professor'], ['Associate Professor'], ['Product Manager'], ['Senior Software Engineer'], ['Senior Software Developer'], ['Business Developer'], ['Assistant Developer'], ['Assistant Manager'], ['Data Developer'], ['Software developer', 'Software Developer', 'Software Developmer'], ['Sofware Engineer', 'Software Engineer'], ['Systems Engineer', 'system engineer'], ['Member of Technical Staff'], ['Student Technical Assistant']]
# 48
# Engineer
# Descriptive Terms: Engineer
# --------------------------------------------------
# koganti rakesh
# Aviral Sahai
# sarthak mall
# Udit Agarwal
# deepak irukula
# Sunil Kumar
# Tejaswi Reddy
# Rahul Sharma
# Harsh Lalwani
# Sapan Diwakar
# Mayank Tuteja
# Sandeep Goyal
# Ankit Paharia
# Prateek Khandelwal
# Ankit Gupta
# shailesh kumar
# Ajit Abhipallav
# Dinesh Pathak
# Arpit Mittal
# Krishna Murthy P.V.N.S.S
# Aman Mamgain
# Mragank Tolwani
# sumit gaur
# Lalit Pathak
# Shubham Jain
# Mayank Gupta
# Avinash Kumar Chaudhary
# Navneet Sinha
# manish aswani
# Naveen Shukla
# Sharath Naik
# Chandresh Bhardwaj
# Vamsi Krishna
# Digvijay Singh
# Amit Meena
# Jayendra Singh
# Keshav Maheshwari
# vidyashankar sahu
# Gaurav Kaushik
# Mohit Bansal
# Amrit Jangid
# Naveen Chalasani
#
# Software
# Descriptive Terms: Software
# --------------------------------------------------------------------------
# Sushil Kumar
# Akshat Sapra
# seshank koganti
# Viswash Pratap Singh
# Ruben Roy
# Naveen Bandlamoodi
# Anoop Mishra
# Pritam Kumar
# Amar deep gupta
# Hemant Pawar
# Abhishek Jha
# akshay khare
# Vinay Kumar
# Abhishek Kumar
# Aman Agarwal
# Dheerendra kumar
# Aman Singh
# Saurabh Singh
# Mohit Kumar Lal
#
# Intern
# Writer
# Descriptive Terms:
# -----------------------------
# Yeswanth Mocharla
# Abhishek (Nehra)
# Vratika Ghatiya
# sai kiran nagaragiri
# ankit bathla
# Mohammad Maaz Khan
# Uma Sharma
# Jatin Mehta
# Ravi Kant
# Nayan Singhal
#
# ECE
# Student
# Descriptive Terms: Student
# -----------------------------------
# Manu Saxena
# Abhimanyu Singh
# Monica Singh
# ravinder naik azmeera
# Jyoti Singh
# Vishal Srivastava
# Aman Agarwal
# Jai Mishra
# Upendra gupta
# Shivlal Dhundhwal
# Amarnath kumar
# Nishtha Rai
# Vikhyat Tandon
# Shubham Tyagi
# siyaram malav
# manish kumar
# Sumit Kumar
# Amit Kumar Singh
# Shailendra Pratap Singh
# Ashutosh Gupta
# Deepak kumhar
# GAURAV VERMA
# Rishabh Chandel
# Navaz Mannan
# Sidharth Singla
# Talha Khan
# ANUJ SHARMA
# Ashok Danga
# Pramiti Goel
# Namrata singh chauhan
# Aaquib Khwaja
# Shreya Singh
# Pretty Meena
# Shiv Shankar Verma
# amanraj varshney
# Aman Aggarwal
# Divanshu Garg
#
# Descriptive Terms:
# ------------------------------------------------
# Rohit Wadhwa
# manoj verma
#
# {'Software': 1, 'Sofware': 1, 'Engineer': 2}
# ['Software', 'Sofware', 'Engineer']
# set(['Engineer'])
# {'Developmer': 1, 'Developer': 1, 'developer': 1, 'Software': 3}
# ['Developmer', 'Developer', 'developer', 'Software']
# set(['Software'])
# {'Intern': 1, 'Writer': 1}
# ['Intern', 'Writer']
# set([])
# {'ECE': 1, 'Student': 2}
# ['ECE', 'Student']
# set(['Student'])
# {'system': 1, 'engineer': 1, 'Systems': 1, 'Engineer': 1}
# ['system', 'engineer', 'Systems', 'Engineer']
# set([])
