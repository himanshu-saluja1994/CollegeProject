# %%
from linkedin import linkedin

# Define CONSUMER_KEY, CONSUMER_SECRET,  
# USER_TOKEN, and USER_SECRET from the credentials 
# provided in your LinkedIn application

CONSUMER_KEY = '75ytlq367qaqac'
CONSUMER_SECRET = 'bFhiobRqAQIcx8JZ'
USER_TOKEN = '53cab7c3-f3c5-4037-92f0-2ad8a5cc3c34'
USER_SECRET = 'b4b71173-0fe5-4c1e-bbd4-a9fdcd98aa37'

RETURN_URL = '' # Not required for developer authentication

# Instantiate the developer authentication class

auth = linkedin.LinkedInDeveloperAuthentication(CONSUMER_KEY, CONSUMER_SECRET, 
		                                USER_TOKEN, USER_SECRET, 
						                                RETURN_URL, 
										                                permissions=linkedin.PERMISSIONS.enums.values())

# Pass it in to the app...

app = linkedin.LinkedInApplication(auth)

# Use the app...

app.get_profile()

import json

connections = app.get_connections()

connections_data = 'linkedin_connections.json'

f = open(connections_data,'w')
f.write(json.dumps(connections,indent=1))
f.close()

my_positions = app.get_profile(selectors=['positions'])
print json.dumps(my_positions, indent=1)

connection_id = connections['values'][0]['id']
connection_positions = app.get_profile(member_id=connection_id, 
		                                       selectors=['positions'])
print json.dumps(connection_positions, indent=1)
# Out:
# {
#  "positions": {
#   "_total": 4,
#   "values": [
#    {
#     "company": {
#      "id": 8641,
#      "name": "HT Media Ltd"
#     },
#     "id": 608190944,
#     "isCurrent": true,
#     "title": "Product Engineer"
#    },
#    {
#     "startDate": {
#      "year": 2011,
#      "month": 10
#     },
#     "endDate": {
#      "year": 2014,
#      "month": 5
#     },
#     "title": "Student Network Administrator - INDEM",
#     "company": {
#      "id": 497317,
#      "name": "Indian Institute of Information Technology, Allahabad, India"
#     },
#     "summary": "As a part of the INDEM Club, for the first 6-7 months I spent time in learning and understanding about the technologies and internet of our college, then after spent time in improving the college internet and LAN facility. This is an excellent position, as I got to be a team member once and eventually from 3rd year onwards I led a team of talented juniors.",
#     "isCurrent": false,
#     "id": 570085959
#    },
#    {
#     "startDate": {
#      "year": 2013,
#      "month": 5
#     },
#     "endDate": {
#      "year": 2013,
#      "month": 6
#     },
#     "title": "Intern",
#     "company": {
#      "id": 166474,
#      "name": "TomTom, Pune"
#     },
#     "summary": "Developed a software module for Automation of a website using Selenium web framework with Core Engineering Team.",
#     "isCurrent": false,
#     "id": 518015174
#    },
#    {
#     "startDate": {
#      "year": 2012,
#      "month": 1
#     },
#     "endDate": {
#      "year": 2012,
#      "month": 12
#     },
#     "title": "Member - Dance Club",
#     "company": {
#      "id": 497317,
#      "name": "Indian Institute of Information Technology, Allahabad, India"
#     },
#     "isCurrent": false,
#     "id": 570085989
#    }
#   ]
#  }
# }
# {
#  "positions": {
#   "_total": 1,
#   "values": [
#    {
#     "startDate": {
#      "year": 2010,
#      "month": 4
#     },
#     "title": "IT Company",
#     "company": {
#      "id": 3072577,
#      "name": "Shiksha Infotech Pvt. Ltd."
#     },
#     "summary": "A STRONG FOUNDATION:\nEstablished in 2010 by IITians, Shiksha Infotech is a fast-growing, software development company in India, offering world class services and solutions to customers Globally. We are today a 150 + people company, having a strong presence with offices in Bangalore, Pune, New Delhi and Bikaner. Our High values, Innovation and Customer centric approach and Commitment to deliver at lower cost, fast speed and better quality has ensured us a 100 % growth year on year in a recession hit market.\nOur Engagement models are aligned with business outcomes and risk/reward incentives to create strategic alignment.",
#     "isCurrent": true,
#     "id": 353322532
#    }
#   ]
#  }
# }

# %%
import json

connections = app.get_connections()

connections_data = 'linkedin_connections.json'

f = open(connections_data, 'w')
f.write(json.dumps(connections, indent=1))
f.close()

# %%
from prettytable import PrettyTable # pip install prettytable

pt = PrettyTable(field_names=['Name', 'Location'])
pt.align = 'l'

[ pt.add_row((c['firstName'] + ' ' + c['lastName'], c['location']['name'])) 
  for c in connections['values']
      if c.has_key('location')]

print pt
# Out:
# +----------------------------------------------------+--------------------------------+
# | Name                                               | Location                       |
# +----------------------------------------------------+--------------------------------+
# | Shiksha Infotech                                   | Bengaluru Area, India          |
# | Praisia Technologies                               | New Delhi Area, India          |
# | Tulika Rani                                        | Gurgaon, India                 |
# | Divyamini Jain_Hiring for Snapdeal (Product/ Tech) | New Delhi Area, India          |
# | Bhawna Chandola                                    | New Delhi Area, India          |
# | Parnika Joel                                       | New Delhi Area, India          |
# | Pooja Chaudhary                                    | New Delhi Area, India          |
# | Anil Chandra                                       | Bengaluru Area, India          |
# | Manu Saxena                                        | Jaipur Area, India             |
# | Aparna Khanna                                      | New Delhi Area, India          |
# | koganti rakesh                                     | India                          |
# | Deepak Gupta                                       | New Delhi Area, India          |
# | Mohit Kumar Lal                                    | Mumbai Area, India             |
# | Saurabh Singh                                      | Greater Seattle Area           |
# | Aman Agarwal                                       | Agra Area, India               |
# | HARI OM MEENA                                      | Jodhpur Area, India            |
# | Rohit Wadhwa                                       | San Francisco Bay Area         |
# | sai praveen chettupalli                            | New Delhi Area, India          |
# | Amar deep gupta                                    | Bengaluru Area, India          |
# | Rahul Sharma                                       | Bengaluru Area, India          |
# | Pathik Shah                                        | Mumbai Area, India             |
# | Suresh Kumar Chhikara                              | New Delhi Area, India          |
# | Ravi Kiran JP                                      | Dhanbad Area, India            |
# | sai kiran nagaragiri                               | Sultanpur Area, India          |
# | Monark Bag                                         | Ahmedabad Area, India          |
# | Naresh Kumar                                       | Meerut Area, India             |
# | Siri Jakka                                         | Hyderabad Area, India          |
# | Adity Khandaalkar                                  | Bengaluru Area, India          |
# | anil vemula                                        | Hyderabad Area, India          |
# | Krishna Murthy P.V.N.S.S                           | Bengaluru Area, India          |
# | Sandeep Goyal                                      | Bengaluru Area, India          |
# | raja agarwal                                       | Mumbai Area, India             |
# | Smruti Rekha                                       | Bengaluru Area, India          |
# | Sriram Subramanian                                 | Bengaluru Area, India          |
# | Prakash Velpula                                    | Hyderabad Area, India          |
# | Adhishwar Mittal                                   | New Delhi Area, India          |
# | Abhimanyu Singh                                    | Allahabad Area, India          |
# | Udayan Chauhan                                     | New Delhi Area, India          |
# | Prateek Khandelwal                                 | Gurgaon, India                 |
# | Shivay Negi                                        | Hyderabad Area, India          |
# | Rajdeep Dey                                        | Hyderabad Area, India          |
# | Samudrala Kumar                                    | Cochin Area, India             |
# | Jai Mishra                                         | Puruliya Area, India           |
# | Shivam Sahu                                        | Lucknow Area, India            |
# | Rakesh Rocky                                       | Allahabad Area, India          |
# | Shiva Reddy                                        | Hyderabad Area, India          |
# | Akshay Mishra                                      | Jhansi Area, India             |
# | Gagan Sharma                                       | Bareilly Area, India           |
# | Naveen Bandlamoodi                                 | Nizamabad Area, India          |
# | sanjai singh                                       | Sultanpur Area, India          |
# | Suneel Kumar                                       | Gorakhpur Area, India          |
# | Teja Swa                                           | Hyderabad Area, India          |
# | Amarender Kumar                                    | New Delhi Area, India          |
# | krati rastogi                                      | Sikar Area, India              |
# | Saket Reddy                                        | Bengaluru Area, India          |
# | Vamshi Krishna S                                   | Hyderabad Area, India          |
# | Vamsi Krishna                                      | Vijayawada Area, India         |
# +----------------------------------------------------+--------------------------------+

# %%
import json

# See http://developer.linkedin.com/documents/profile-fields#fullprofile
# for details on additional field selectors that can be passed in for
# retrieving additional profile information.

# Display your own positions...

my_positions = app.get_profile(selectors=['positions'])
print json.dumps(my_positions, indent=1)

# Display positions for someone in your network...

# Get an id for a connection. We'll just pick the first one.
connection_id = connections['values'][0]['id']
connection_positions = app.get_profile(member_id=connection_id, 
                                       selectors=['positions'])
print json.dumps(connection_positions, indent=1)
# Out:
# {
#  "positions": {
#   "_total": 4,
#   "values": [
#    {
#     "company": {
#      "id": 8641,
#      "name": "HT Media Ltd"
#     },
#     "id": 608190944,
#     "isCurrent": true,
#     "title": "Product Engineer"
#    },
#    {
#     "startDate": {
#      "year": 2011,
#      "month": 10
#     },
#     "endDate": {
#      "year": 2014,
#      "month": 5
#     },
#     "title": "Student Network Administrator - INDEM",
#     "company": {
#      "id": 497317,
#      "name": "Indian Institute of Information Technology, Allahabad, India"
#     },
#     "summary": "As a part of the INDEM Club, for the first 6-7 months I spent time in learning and understanding about the technologies and internet of our college, then after spent time in improving the college internet and LAN facility. This is an excellent position, as I got to be a team member once and eventually from 3rd year onwards I led a team of talented juniors.",
#     "isCurrent": false,
#     "id": 570085959
#    },
#    {
#     "startDate": {
#      "year": 2013,
#      "month": 5
#     },
#     "endDate": {
#      "year": 2013,
#      "month": 6
#     },
#     "title": "Intern",
#     "company": {
#      "id": 166474,
#      "name": "TomTom, Pune"
#     },
#     "summary": "Developed a software module for Automation of a website using Selenium web framework with Core Engineering Team.",
#     "isCurrent": false,
#     "id": 518015174
#    },
#    {
#     "startDate": {
#      "year": 2012,
#      "month": 1
#     },
#     "endDate": {
#      "year": 2012,
#      "month": 12
#     },
#     "title": "Member - Dance Club",
#     "company": {
#      "id": 497317,
#      "name": "Indian Institute of Information Technology, Allahabad, India"
#     },
#     "isCurrent": false,
#     "id": 570085989
#    }
#   ]
#  }
# }
# {
#  "positions": {
#   "_total": 1,
#   "values": [
#    {
#     "startDate": {
#      "year": 2010,
#      "month": 4
#     },
#     "title": "IT Company",
#     "company": {
#      "id": 3072577,
#      "name": "Shiksha Infotech Pvt. Ltd."
#     },
#     "summary": "A STRONG FOUNDATION:\nEstablished in 2010 by IITians, Shiksha Infotech is a fast-growing, software development company in India, offering world class services and solutions to customers Globally. We are today a 150 + people company, having a strong presence with offices in Bangalore, Pune, New Delhi and Bikaner. Our High values, Innovation and Customer centric approach and Commitment to deliver at lower cost, fast speed and better quality has ensured us a 100 % growth year on year in a recession hit market.\nOur Engagement models are aligned with business outcomes and risk/reward incentives to create strategic alignment.",
#     "isCurrent": true,
#     "id": 353322532
#    }
#   ]
#  }
# }

# %%
my_positions = app.get_profile(selectors=['positions:(company:(name,industry,id))'])
print json.dumps(my_positions, indent=1)
# Out:
# {
#  "positions": {
#   "_total": 4,
#   "values": [
#    {
#     "company": {
#      "id": 8641,
#      "name": "HT Media Ltd"
#     }
#    },
#    {
#     "company": {
#      "id": 497317,
#      "name": "Indian Institute of Information Technology, Allahabad, India"
#     }
#    },
#    {
#     "company": {
#      "id": 166474,
#      "name": "TomTom, Pune"
#     }
#    },
#    {
#     "company": {
#      "id": 497317,
#      "name": "Indian Institute of Information Technology, Allahabad, India"
#     }
#    }
#   ]
#  }
# }

# %%
import os
import csv
from collections import Counter
from operator import itemgetter
from prettytable import PrettyTable

# XXX: Place your "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings at the following
# location: resources/ch03-linkedin/my_connections.csv

CSV_FILE = os.path.join('connections.csv')

# Define a set of transforms that converts the first item
# to the second item. Here, we're simply handling some
# commonly known abbreviations, stripping off common suffixes, 
# etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)
[pt.add_row([company, freq]) 
 for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print pt
# Out:
# +----------------------------------------------------------------------------------+------+
# | Company                                                                          | Freq |
# +----------------------------------------------------------------------------------+------+
# | Indian Institute of Information Technology, Allahabad, India                     | 12   |
# | IIIT Allahabad                                                                   | 10   |
# | Amazon                                                                           | 5    |
# | Juniper Networks                                                                 | 4    |
# | Mozilla                                                                          | 4    |
# | Flipkart.com                                                                     | 4    |
# | MAQ Software                                                                     | 3    |
# | Snapdeal                                                                         | 3    |
# | Directi                                                                          | 3    |
# | SAP                                                                              | 2    |
# | Adobe                                                                            | 2    |
# | Samsung R&D Institute India                                                      | 2    |
# | IIITA                                                                            | 2    |
# | Wikimedia Foundation                                                             | 2    |
# | Morgan Stanley                                                                   | 2    |
# | Indian Institute of Information Technology, Allahabad                            | 2    |
# | Mahindra Comviva                                                                 | 2    |
# | Techical Society of Indian Institute of Information Technology, Allahabad, India | 2    |
# | hike messenger                                                                   | 2    |
# | Goibibo                                                                          | 2    |
# | Citi                                                                             | 2    |
# | TomTom                                                                           | 2    |
# | IIIT ALLAHABAD                                                                   | 2    |
# | iiit allahabad                                                                   | 2    |
# +----------------------------------------------------------------------------------+------+

# %%
import os
import csv
from operator import itemgetter
from collections import Counter
from prettytable import PrettyTable

# XXX: Place your "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings at the following
# location: resources/ch03-linkedin/my_connections.csv

CSV_FILE = os.path.join('connections.csv')

transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO."
# Other variations could be handled as well, such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Job Title'].split('/')
                  if contact['Job Title'].strip() != ''])

# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print pt

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 2]
print pt
# Out:
# +-------------------------------+------+
# | Title                         | Freq |
# +-------------------------------+------+
# | Software Engineer             | 19   |
# | Student                       | 17   |
# | student                       | 8    |
# | Software Developer            | 5    |
# | Intern                        | 4    |
# | Student Ambassador            | 3    |
# | SDE                           | 3    |
# | Senior Software Engineer      | 2    |
# | Software Engineering Intern   | 2    |
# | Software Development Engineer | 2    |
# | Technical Team Member         | 2    |
# | IT Consultant                 | 2    |
# +-------------------------------+------+
# +---------------+------+
# | Token         | Freq |
# +---------------+------+
# | Software      | 43   |
# | Engineer      | 35   |
# | Student       | 24   |
# | Developer     | 11   |
# | Intern        | 9    |
# | student       | 8    |
# | Assistant     | 7    |
# | Engineering   | 7    |
# | Development   | 7    |
# | Associate     | 7    |
# | Manager       | 7    |
# | developer     | 6    |
# | Senior        | 6    |
# | Technical     | 6    |
# | Placement     | 6    |
# | Ambassador    | 5    |
# | Member        | 5    |
# | Test          | 4    |
# | Coordinator   | 4    |
# | and           | 4    |
# | Technology    | 4    |
# | SDE           | 4    |
# | Analyst       | 3    |
# | Training      | 3    |
# | Head          | 3    |
# | Professor     | 3    |
# | Team          | 3    |
# | Design        | 3    |
# | Consultant    | 3    |
# | Programmer    | 3    |
# | Web           | 2    |
# | Recruiter     | 2    |
# | Internship    | 2    |
# | Company       | 2    |
# | Director      | 2    |
# | Officer       | 2    |
# | Research      | 2    |
# | Staff         | 2    |
# | Firefox       | 2    |
# | Undergraduate | 2    |
# | Campus        | 2    |
# | Cell          | 2    |
# | engineer      | 2    |
# | Allahabad     | 2    |
# | Data          | 2    |
# | Information   | 2    |
# | Executive     | 2    |
# | Product       | 2    |
# +---------------+------+

# %%
from geopy import geocoders

GEO_APP_KEY = 'AjBl_exEOrwQdY8PVGenQj89LFdjxKn2ciZKAwX-Gfn2rbESjpcwnaQyokPAwOGU' # XXX: Get this from https://www.bingmapsportal.com
g = geocoders.Bing(GEO_APP_KEY)
print g.geocode("Nashville", exactly_one=False)
# Out:
# [Location((36.1678390503, -86.7781600952, 0.0)), Location((39.2085494995, -86.2481384277, 0.0)), Location((38.3436813354, -89.3826370239, 0.0)), Location((33.9479293823, -93.847038269, 0.0)), Location((35.9743309021, -77.9649505615, 0.0))]

# %%
from geopy import geocoders

GEO_APP_KEY = 'AjBl_exEOrwQdY8PVGenQj89LFdjxKn2ciZKAwX-Gfn2rbESjpcwnaQyokPAwOGU' # XXX: Get this from https://www.bingmapsportal.com
g = geocoders.Bing(GEO_APP_KEY)

transforms = [('Greater ', ''), (' Area', '')]

results = {}
for c in connections['values']:
    if not c.has_key('location'): continue
        
    transformed_location = c['location']['name']
    for transform in transforms:
        transformed_location = transformed_location.replace(*transform)
    geo = g.geocode(transformed_location, exactly_one=False)
    if geo == []: continue
    results.update({ c['location']['name'] : geo })
    
print json.dumps(results, indent=1)

# %%
import re

# Most results contain a response that can be parsed by
# picking out the first two consecutive upper case letters 
# as a clue for the state
pattern = re.compile('.*([A-Z]{2}).*')
    
def parseStateFromBingResult(r):
    result = pattern.search(r[0][0])
    if result == None: 
        print "Unresolved match:", r
        return "???"
    elif len(result.groups()) == 1:
        print result.groups()
        return result.groups()[0]
    else:
        print "Unresolved match:", result.groups()
        return "???"

    
transforms = [('Greater ', ''), (' Area', '')]

results = {}
for c in connections['values']:
    if not c.has_key('location'): continue
    if not c['location']['country']['code'] == 'us': continue
        
    transformed_location = c['location']['name']
    for transform in transforms:
        transformed_location = transformed_location.replace(*transform)
    
    geo = g.geocode(transformed_location, exactly_one=False)
    if geo == []: continue
    parsed_state = parseStateFromBingResult(geo)
    if parsed_state != "???":
        results.update({c['location']['name'] : parsed_state})
    
print json.dumps(results, indent=1)
# Out:
# (u'WA',)
# (u'CA',)
# (u'NY',)
# (u'CA',)
# (u'TX',)
# (u'CA',)
# (u'CA',)
# (u'VT',)
# {
#  "Greater Seattle Area": "WA",
#  "Greater Los Angeles Area": "CA",
#  "Glens Falls, New York Area": "NY",
#  "Dallas/Fort Worth Area": "TX",
#  "San Francisco Bay Area": "CA",
#  "Burlington, Vermont Area": "VT"
# }

# %%
import os
import json
from IPython.display import IFrame
from IPython.core.display import display

# Load in a data structure mapping state names to codes.
# e.g. West Virginia is WV
codes = json.loads(open('states.json').read())

from collections import Counter
c = Counter([r[1] for r in results.items()])
states_freqs = { codes[k] : v for (k,v) in c.items() }

# Lace in all of the other states and provide a minimum value for each of them
states_freqs.update({v : 0.5 for v in codes.values() if v not in states_freqs.keys() })

# Write output to file
f = open('states_freq.json', 'w')
f.write(json.dumps(states_freqs, indent=1))
f.close()

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

display(IFrame('viz/cartogram.html', '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="viz/cartogram.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import os
import csv
from nltk.metrics.distance import jaccard_distance


CSV_FILE = os.path.join('connections.csv')

DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or clusters.has_key(title2) and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))

            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)

    # Flatten out clusters

    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]

    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts


clustered_contacts = cluster_contacts_by_title(CSV_FILE)
print clustered_contacts
for titles in clustered_contacts:
    common_titles_heading = 'Common Titles: ' + ', '.join(titles)

    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms_heading = 'Descriptive Terms: ' \
        + ', '.join(descriptive_terms)
    print descriptive_terms_heading
    print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
    print '\n'.join(clustered_contacts[titles])
    print
# Out:
# {('Software Test Engineer', 'Software Engineer'): ['Rahul Sharma', 'koganti rakesh', 'Krishna Murthy P.V.N.S.S', 'Navneet Sinha', 'Prateek Khandelwal', 'Naveen Chalasani', 'sarthak mall', 'Udit Agarwal', 'Gaurav Kaushik', 'Mragank Tolwani', 'manish aswani', 'Ankit Gupta', 'sumit gaur', 'shailesh kumar', 'Mohit Bansal', 'vidyashankar sahu', 'amardeep gupta', 'Sapan Diwakar', 'Shubham Jain', 'Amrit Jangid'], ('Placement Cell', 'Placement Cell Co-ordinator'): ['Adhishwar Mittal', 'divya porwal'], ('Software Developer', 'Software Developer Internship', 'Senior Software Developer'): ['Ruben Roy', 'Mohit Kumar Lal', 'Ashish Sinha', 'Pritam Kumar', 'Saurabh Singh', 'Abhishek Kumar', 'akshay khare'], ('Software Development Engineer', 'Software Engineer', 'Software Development Engineer II'): ['Rahul Sharma', 'Krishna Murthy P.V.N.S.S', 'Akshat Sapra', 'Navneet Sinha', 'Prateek Khandelwal', 'Naveen Chalasani', 'sarthak mall', 'Udit Agarwal', 'Gaurav Kaushik', 'Digvijay Singh', 'Mragank Tolwani', 'manish aswani', 'Ankit Gupta', 'sumit gaur', 'Sandeep Goyal', 'shailesh kumar', 'Mohit Bansal', 'vidyashankar sahu', 'amardeep gupta', 'Sapan Diwakar', 'Shubham Jain', 'Amrit Jangid'], ('Member of Technical Staff', 'Member of Technical Staff 1'): ['Abhinav Vishwa', 'Prakhar Agrawal'], ('Senior Software Engineer', 'Software Engineer'): ['Rahul Sharma', 'Krishna Murthy P.V.N.S.S', 'Navneet Sinha', 'Prateek Khandelwal', 'Naveen Chalasani', 'sarthak mall', 'Udit Agarwal', 'Gaurav Kaushik', 'Mragank Tolwani', 'manish aswani', 'Ankit Gupta', 'sumit gaur', 'shailesh kumar', 'Akhil Yadav', 'Mohit Bansal', 'vidyashankar sahu', 'amardeep gupta', 'Sapan Diwakar', 'Monika Agrawal', 'Shubham Jain', 'Amrit Jangid'], ('Associate Software developer', 'Software developer'): ['Viswash Pratap Singh', 'Dheerendra kumar'], ('Assistant Software Engineer', 'Software Engineer'): ['Rahul Sharma', 'deepak irukula', 'Krishna Murthy P.V.N.S.S', 'Navneet Sinha', 'Prateek Khandelwal', 'Naveen Chalasani', 'sarthak mall', 'Udit Agarwal', 'Gaurav Kaushik', 'Mragank Tolwani', 'manish aswani', 'Ankit Gupta', 'sumit gaur', 'shailesh kumar', 'Mohit Bansal', 'vidyashankar sahu', 'amardeep gupta', 'Sapan Diwakar', 'Shubham Jain', 'Amrit Jangid'], ('Software Development Engineer in Test', 'Software Development Engineer', 'Software Test Engineer'): ['koganti rakesh', 'Arpit Mittal', 'Akshat Sapra', 'Digvijay Singh'], ('Associate Software Engineer', 'Software Engineer'): ['Rahul Sharma', 'Krishna Murthy P.V.N.S.S', 'Navneet Sinha', 'Prateek Khandelwal', 'Naveen Chalasani', 'Amit Meena', 'sarthak mall', 'Udit Agarwal', 'Gaurav Kaushik', 'Mragank Tolwani', 'manish aswani', 'Ankit Gupta', 'sumit gaur', 'shailesh kumar', 'Mohit Bansal', 'vidyashankar sahu', 'amardeep gupta', 'Sapan Diwakar', 'Shubham Jain', 'Amrit Jangid'], ('Software Design Engineer', 'Software Engineer'): ['Rahul Sharma', 'Krishna Murthy P.V.N.S.S', 'Navneet Sinha', 'Prateek Khandelwal', 'Naveen Chalasani', 'sarthak mall', 'Udit Agarwal', 'Gaurav Kaushik', 'Ajit Abhipallav', 'Mragank Tolwani', 'manish aswani', 'Ankit Gupta', 'sumit gaur', 'shailesh kumar', 'Mohit Bansal', 'vidyashankar sahu', 'amardeep gupta', 'Sapan Diwakar', 'Shubham Jain', 'Amrit Jangid'], ('Overall Placement Coordinator', 'Placement Coordinator'): ['Aaquib Khwaja', 'Placement Office IIIT Allahabad', 'Abhinav Gupta'], ('Firefox Student Ambassador', 'Student Ambassador'): ['Harshit Gupta', 'Vishnu Ks', 'Ravi Kiran JP', 'Charul Agrawal']}
# Descriptive Terms: Software, Engineer
# --------------------------------------------------------
# Rahul Sharma
# koganti rakesh
# Krishna Murthy P.V.N.S.S
# Navneet Sinha
# Prateek Khandelwal
# Naveen Chalasani
# sarthak mall
# Udit Agarwal
# Gaurav Kaushik
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# shailesh kumar
# Mohit Bansal
# vidyashankar sahu
# amardeep gupta
# Sapan Diwakar
# Shubham Jain
# Amrit Jangid
#
# Descriptive Terms: Cell, Placement
# ----------------------------------------------------------
# Adhishwar Mittal
# divya porwal
#
# Descriptive Terms: Software, Developer
# -------------------------------------------------------------------------------------------
# Ruben Roy
# Mohit Kumar Lal
# Ashish Sinha
# Pritam Kumar
# Saurabh Singh
# Abhishek Kumar
# akshay khare
#
# Descriptive Terms: Engineer, Software
# -------------------------------------------------------------------------------------------------
# Rahul Sharma
# Krishna Murthy P.V.N.S.S
# Akshat Sapra
# Navneet Sinha
# Prateek Khandelwal
# Naveen Chalasani
# sarthak mall
# Udit Agarwal
# Gaurav Kaushik
# Digvijay Singh
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# Sandeep Goyal
# shailesh kumar
# Mohit Bansal
# vidyashankar sahu
# amardeep gupta
# Sapan Diwakar
# Shubham Jain
# Amrit Jangid
#
# Descriptive Terms: Member, of, Technical, Staff
# ---------------------------------------------------------------------
# Abhinav Vishwa
# Prakhar Agrawal
#
# Descriptive Terms: Software, Engineer
# ----------------------------------------------------------
# Rahul Sharma
# Krishna Murthy P.V.N.S.S
# Navneet Sinha
# Prateek Khandelwal
# Naveen Chalasani
# sarthak mall
# Udit Agarwal
# Gaurav Kaushik
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# shailesh kumar
# Akhil Yadav
# Mohit Bansal
# vidyashankar sahu
# amardeep gupta
# Sapan Diwakar
# Monika Agrawal
# Shubham Jain
# Amrit Jangid
#
# Descriptive Terms: Software, developer
# ---------------------------------------------------------------
# Viswash Pratap Singh
# Dheerendra kumar
#
# Descriptive Terms: Software, Engineer
# -------------------------------------------------------------
# Rahul Sharma
# deepak irukula
# Krishna Murthy P.V.N.S.S
# Navneet Sinha
# Prateek Khandelwal
# Naveen Chalasani
# sarthak mall
# Udit Agarwal
# Gaurav Kaushik
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# shailesh kumar
# Mohit Bansal
# vidyashankar sahu
# amardeep gupta
# Sapan Diwakar
# Shubham Jain
# Amrit Jangid
#
# Descriptive Terms: Software, Engineer
# -----------------------------------------------------------------------------------------------------------
# koganti rakesh
# Arpit Mittal
# Akshat Sapra
# Digvijay Singh
#
# Descriptive Terms: Software, Engineer
# -------------------------------------------------------------
# Rahul Sharma
# Krishna Murthy P.V.N.S.S
# Navneet Sinha
# Prateek Khandelwal
# Naveen Chalasani
# Amit Meena
# sarthak mall
# Udit Agarwal
# Gaurav Kaushik
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# shailesh kumar
# Mohit Bansal
# vidyashankar sahu
# amardeep gupta
# Sapan Diwakar
# Shubham Jain
# Amrit Jangid
#
# Descriptive Terms: Software, Engineer
# ----------------------------------------------------------
# Rahul Sharma
# Krishna Murthy P.V.N.S.S
# Navneet Sinha
# Prateek Khandelwal
# Naveen Chalasani
# sarthak mall
# Udit Agarwal
# Gaurav Kaushik
# Ajit Abhipallav
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# shailesh kumar
# Mohit Bansal
# vidyashankar sahu
# amardeep gupta
# Sapan Diwakar
# Shubham Jain
# Amrit Jangid
#
# Descriptive Terms: Coordinator, Placement
# -------------------------------------------------------------------
# Aaquib Khwaja
# Placement Office IIIT Allahabad
# Abhinav Gupta
#
# Descriptive Terms: Ambassador, Student
# -------------------------------------------------------------
# Harshit Gupta
# Vishnu Ks
# Ravi Kiran JP
# Charul Agrawal

# %%
import json
import os
from IPython.display import IFrame
from IPython.core.display import display

data = {"label" : "name", "temp_items" : {}, "items" : []} 
for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if data['temp_items'].has_key(descriptive_terms):
        data['temp_items'][descriptive_terms].extend([{'name' : cc } for cc 
            in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name' : cc } for cc 
            in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name" : "%s (%s)" % (descriptive_terms, 
        len(data['temp_items'][descriptive_terms]),),
                              "children" : [i for i in 
                              data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

TEMPLATE = 'viz/dojo_tree.html.template'                                                
OUT = 'viz/dojo_tree.html'

viz_file = 'viz/dojo_tree.html'

t = open(TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4))
f.close()

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

display(IFrame(viz_file, '400px', '600px'))
# Out:
#         <iframe
#             width="400px"
#             height=600px"
#             src="viz/dojo_tree.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import os
import csv
import random
from nltk.metrics.distance import jaccard_distance
from cluster import HierarchicalClustering

CSV_FILE = os.path.join('connections.csv')

OUT_FILE = 'viz/d3-data.json'


DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance


SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)

    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]

    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts

def display_output(clustered_contacts):
    
    for titles in clustered_contacts:
        common_titles_heading = 'Common Titles: ' + ', '.join(titles)

        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
            + ', '.join(descriptive_terms)
        print descriptive_terms_heading
        print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
        print '\n'.join(clustered_contacts[titles])
        print

def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))

        json_output['children'].append({'name' : ', '.join(descriptive_terms)[:30], 
                                    'children' : [ {'name' : c.decode('utf-8', 'replace')} for c in clustered_contacts[titles] ] } )
    
        f = open(OUT_FILE, 'w')
        f.write(json.dumps(json_output, indent=1))
        f.close()
    
clustered_contacts = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts)
write_d3_json_output(clustered_contacts)
# Out:
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Ruben Roy
# Rahul Sharma
# Mohit Kumar Lal
# koganti rakesh
# Sumit Kumar Satnalika
# deepak irukula
# Chandresh Bhardwaj
# Arpit Mittal
# Lakshya Goel
# Krishna Murthy P.V.N.S.S
# Akshat Sapra
# Suyash Agarwal
# Navneet Sinha
# Prateek Khandelwal
# Ashish Sinha
# Pritam Kumar
# Akshay Gupta
# Naveen Chalasani
# Amit Meena
# sarthak mall
# Saurabh Singh
# Abhishek Kumar
# Udit Agarwal
# Prabhat Kumar
# Dinesh Pathak
# Gaurav Kaushik
# Ajit Abhipallav
# Digvijay Singh
# Mragank Tolwani
# manish aswani
# Ankit Gupta
# sumit gaur
# Viswash Pratap Singh
# Sandeep Goyal
# shailesh kumar
# Dheerendra kumar
# Akhil Yadav
# Mohit Bansal
# vidyashankar sahu
# akshay khare
# amardeep gupta
# Sapan Diwakar
# Monika Agrawal
# Shubham Jain
# Amrit Jangid
# Adity Khandaalkar
#
# Descriptive Terms: Intern
# ------------------------------------
# Vratika Ghatiya
# Uma Sharma
# Mohammad Maaz Khan
# Nayan Singhal
# Ravi Kant
#
# Descriptive Terms: Programmer
# ---------------------------------------------
# JP Godara
# Ramanan Ramesh
#
# Descriptive Terms: Member, of, Technical, Staff
# ---------------------------------------------------------------------
# Abhinav Vishwa
# Prakhar Agrawal
#
# Descriptive Terms: Student
# ---------------------------------------------------------------------------------------------
# GAURAV VERMA
# Aaquib Khwaja
# Harshit Gupta
# Navaz Mannan
# Vishnu Ks
# Ravi Kiran JP
# siyaram malav
# Monica Singh
# Nishtha Rai
# Shubham Tyagi
# Charul Agrawal
# Aman Agarwal
# Shiv Shankar Verma
# Pretty Meena
# Divanshu Garg
# Abhimanyu Singh
# Sidharth Singla
# Vikhyat Tandon
# Shreya Singh
# Upendra gupta
# Ashok Danga
# Aman Aggarwal
# Manu Saxena
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------
# Jag Rawat
# Praisia Technologies
# Adhishwar Mittal
# nipun lall
# Siri Jakka
# Vedavyas Chigurupati
#
# Descriptive Terms: Consultant
# ----------------------------------------
# ASHISH KUMAR SAHU
# raja agarwal
# Pradeep Mishra
#
# Descriptive Terms: Cell, Placement
# ----------------------------------------------------------
# Adhishwar Mittal
# divya porwal
#
# Descriptive Terms: of, Head
# --------------------------------------------
# Raj Medepalli
# Pathik Shah
#
# Descriptive Terms: Director, Engineering, -
# ----------------------------------------------------------------------------------
# Sriram Subramanian
# Prashanth Ashwathnarayan
#
# Descriptive Terms: Coordinator, Placement
# -------------------------------------------------------------------
# Aaquib Khwaja
# Placement Office IIIT Allahabad
# Abhinav Gupta

# %%
import os
from IPython.display import IFrame
from IPython.core.display import display

viz_file = 'viz/node_link_tree.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="viz/node_link_tree.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
