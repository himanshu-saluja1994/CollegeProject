# %%
from linkedin import linkedin

# Define CONSUMER_KEY, CONSUMER_SECRET,  
# USER_TOKEN, and USER_SECRET from the credentials 
# provided in your LinkedIn application

CONSUMER_KEY = '75ytlq367qaqac'
CONSUMER_SECRET = 'bFhiobRqAQIcx8JZ'
USER_TOKEN = '53cab7c3-f3c5-4037-92f0-2ad8a5cc3c34'
USER_SECRET = 'b4b71173-0fe5-4c1e-bbd4-a9fdcd98aa37'

RETURN_URL = '' # Not required for developer authentication

# Instantiate the developer authentication class

auth = linkedin.LinkedInDeveloperAuthentication(CONSUMER_KEY, CONSUMER_SECRET, 
		                                USER_TOKEN, USER_SECRET, 
						                                RETURN_URL, 
										                                permissions=linkedin.PERMISSIONS.enums.values())

# Pass it in to the app...

app = linkedin.LinkedInApplication(auth)

# Use the app...

app.get_profile()

import json

connections = app.get_connections()

connections_data = 'linkedin_connections.json'

f = open(connections_data,'w')
f.write(json.dumps(connections,indent=1))
f.close()

my_positions = app.get_profile(selectors=['positions'])
print json.dumps(my_positions, indent=1)

connection_id = connections['values'][0]['id']
connection_positions = app.get_profile(member_id=connection_id, 
		                                       selectors=['positions'])
print json.dumps(connection_positions, indent=1)
# Out:
# ---------------------------------------------------------------------------
# LinkedInError                             Traceback (most recent call last)
# <ipython-input-1-22fa1d40c725> in <module>()
#      25 # Use the app...
#      26
# ---> 27 app.get_profile()
#      28
#      29 import json
#
# /usr/local/lib/python2.7/dist-packages/linkedin/linkedin.pyc in get_profile(self, member_id, member_url, selectors, params, headers)
#     177
#     178         response = self.make_request('GET', url, params=params, headers=headers)
# --> 179         raise_for_error(response)
#     180         return response.json()
#     181
#
# /usr/local/lib/python2.7/dist-packages/linkedin/utils.pyc in raise_for_error(response)
#      61                 message = '%s: %s' % (response.get('error', error.message),
#      62                                       response.get('error_description', 'Unknown Error'))
# ---> 63                 raise LinkedInError(message)
#      64             else:
#      65                 raise LinkedInError(error.message)
#
# LinkedInError: 500 Server Error: Internal Server Error: Unknown Error

# %%
import json

connections = app.get_connections()

connections_data = 'linkedin_connections.json'

f = open(connections_data, 'w')
f.write(json.dumps(connections, indent=1))
f.close()
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-2-77493780e29f> in <module>()
#       1 import json
#       2
# ----> 3 connections = app.get_connections()
#       4
#       5 connections_data = 'linkedin_connections.json'
#
# /root/anaconda/lib/python2.7/site-packages/linkedin/linkedin.pyc in get_connections(self, member_id, member_url, selectors, params, headers)
#     216             url = '%s:(%s)' % (url, LinkedInSelector.parse(selectors))
#     217
# --> 218         response = self.make_request('GET', url, params=params, headers=headers)
#     219         raise_for_error(response)
#     220         return response.json()
#
# /root/anaconda/lib/python2.7/site-packages/linkedin/linkedin.pyc in make_request(self, method, url, data, params, headers, timeout)
#     163             params.update({'oauth2_access_token': self.authentication.token.access_token})
#     164
# --> 165         return requests.request(method.upper(), url, **kw)
#     166
#     167     def get_profile(self, member_id=None, member_url=None, selectors=None,
#
# /root/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /root/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     381             'allow_redirects': allow_redirects,
#     382         }
# --> 383         resp = self.send(prep, **send_kwargs)
#     384
#     385         return resp
#
# /root/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     484         start = datetime.utcnow()
#     485         # Send the request
# --> 486         r = adapter.send(request, **kwargs)
#     487         # Total elapsed time of the request (approximately)
#     488         r.elapsed = datetime.utcnow() - start
#
# /root/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     383         except (_SSLError, _HTTPError) as e:
#     384             if isinstance(e, _SSLError):
# --> 385                 raise SSLError(e)
#     386             elif isinstance(e, TimeoutError):
#     387                 raise Timeout(e)
#
# SSLError: hostname '172.31.1.4' doesn't match either of 'tablet.linkedin.com', 'tablet.www.linkedin.com', 'touch.linkedin.com', 'touch.www.linkedin.com', 'm.linkedin.com', 'api.linkedin.com'

# %%
from prettytable import PrettyTable 

pt = PrettyTable(field_names=['Name', 'Location'])
pt.align = 'l'

[ pt.add_row((c['firstName'] + ' ' + c['lastName'], c['location']['name'])) 
  for c in connections['values']
      if c.has_key('location')]

print ""
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d90d5017b144> in <module>()
#       5
#       6 [ pt.add_row((c['firstName'] + ' ' + c['lastName'], c['location']['name']))
# ----> 7   for c in connections['values']
#       8       if c.has_key('location')]
#       9
#
# NameError: name 'connections' is not defined

# %%
import json

# See http://developer.linkedin.com/documents/profile-fields#fullprofile
# for details on additional field selectors that can be passed in for
# retrieving additional profile information.

# Display your own positions...

my_positions = app.get_profile(selectors=['positions'])
print json.dumps(my_positions, indent=1)

# Display positions for someone in your network...

# Get an id for a connection. We'll just pick the first one.
connection_id = connections['values'][0]['id']
connection_positions = app.get_profile(member_id=connection_id, 
                                       selectors=['positions'])
print json.dumps(connection_positions, indent=1)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# <ipython-input-4-794b0f197f55> in <module>()
#       7 # Display your own positions...
#       8
# ----> 9 my_positions = app.get_profile(selectors=['positions'])
#      10 print json.dumps(my_positions, indent=1)
#      11
#
# /root/anaconda/lib/python2.7/site-packages/linkedin/linkedin.pyc in get_profile(self, member_id, member_url, selectors, params, headers)
#     176             url = '%s:(%s)' % (url, LinkedInSelector.parse(selectors))
#     177
# --> 178         response = self.make_request('GET', url, params=params, headers=headers)
#     179         raise_for_error(response)
#     180         return response.json()
#
# /root/anaconda/lib/python2.7/site-packages/linkedin/linkedin.pyc in make_request(self, method, url, data, params, headers, timeout)
#     163             params.update({'oauth2_access_token': self.authentication.token.access_token})
#     164
# --> 165         return requests.request(method.upper(), url, **kw)
#     166
#     167     def get_profile(self, member_id=None, member_url=None, selectors=None,
#
# /root/anaconda/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      42
#      43     session = sessions.Session()
# ---> 44     return session.request(method=method, url=url, **kwargs)
#      45
#      46
#
# /root/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert)
#     381             'allow_redirects': allow_redirects,
#     382         }
# --> 383         resp = self.send(prep, **send_kwargs)
#     384
#     385         return resp
#
# /root/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     484         start = datetime.utcnow()
#     485         # Send the request
# --> 486         r = adapter.send(request, **kwargs)
#     487         # Total elapsed time of the request (approximately)
#     488         r.elapsed = datetime.utcnow() - start
#
# /root/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     383         except (_SSLError, _HTTPError) as e:
#     384             if isinstance(e, _SSLError):
# --> 385                 raise SSLError(e)
#     386             elif isinstance(e, TimeoutError):
#     387                 raise Timeout(e)
#
# SSLError: hostname '172.31.1.4' doesn't match either of 'tablet.linkedin.com', 'tablet.www.linkedin.com', 'touch.linkedin.com', 'touch.www.linkedin.com', 'm.linkedin.com', 'api.linkedin.com'

# %%
#my_positions = app.get_profile(selectors=['positions:(company:(name,industry,id))'])
#print json.dumps(my_positions, indent=1)

# %%
import os
import csv
from operator import itemgetter
from collections import Counter
from prettytable import PrettyTable

# XXX: Place your "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings at the following
# location: resources/ch03-linkedin/my_connections.csv

CSV_FILE = os.path.join('connections.csv')

transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
print len(contacts)

# Read in a list of titles and split apart
# any combined titles like "President/CEO."
# Other variations could be handled as well, such
# as "President & CEO", "President and CEO", etc.

titles = []
i=0;
for contact in contacts:
    if contact['Job Title']!='':
        i=i+1;
    titles.extend([t.strip() for t in contact['Job Title'].split('/')
                  if contact['Job Title'].strip() != ''])
print i
# Replace common/known abbreviations

for i, _ in enumerate(titles):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(field_names=['Title', 'Freq'])
pt.align = 'l'
c = Counter(titles)
[pt.add_row([title, freq]) 
 for (title, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print ""

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1 and len(token) > 2]
print ""
# Out:
# 319
# 201

# %%
import os
import csv
from collections import Counter
from operator import itemgetter
from prettytable import PrettyTable

# XXX: Place your "Outlook CSV" formatted file of connections from 
# http://www.linkedin.com/people/export-settings at the following
# location: resources/ch03-linkedin/my_connections.csv

CSV_FILE = os.path.join('connections.csv')

# Define a set of transforms that converts the first item
# to the second item. Here, we're simply handling some
# commonly known abbreviations, stripping off common suffixes, 
# etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', ''),
               (' LLC', ''), (' Inc.', ''), (' Inc', '')]

csvReader = csv.DictReader(open(CSV_FILE), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i, _ in enumerate(companies):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

pt = PrettyTable(field_names=['Company', 'Freq'])
pt.align = 'l'
c = Counter(companies)
[pt.add_row([company, freq]) 
 for (company, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 1]
print pt
# Out:
# +----------------------------------------------------------------------------------+------+
# | Company                                                                          | Freq |
# +----------------------------------------------------------------------------------+------+
# | Indian Institute of Information Technology, Allahabad, India                     | 14   |
# | IIIT Allahabad                                                                   | 12   |
# | Amazon                                                                           | 6    |
# | Mozilla                                                                          | 6    |
# | IIIT ALLAHABAD                                                                   | 5    |
# | Juniper Networks                                                                 | 4    |
# | Flipkart.com                                                                     | 4    |
# | MAQ Software                                                                     | 3    |
# | Indian Institute of Information Technology, Allahabad                            | 3    |
# | Snapdeal                                                                         | 3    |
# | HT Media Ltd                                                                     | 3    |
# | Directi                                                                          | 3    |
# | InnoPark(India) Pvt.Ltd                                                          | 2    |
# | Adobe                                                                            | 2    |
# | IIITA                                                                            | 2    |
# | Amazon.com                                                                       | 2    |
# | Wikimedia Foundation                                                             | 2    |
# | Morgan Stanley                                                                   | 2    |
# | Mahindra Comviva                                                                 | 2    |
# | Techical Society of Indian Institute of Information Technology, Allahabad, India | 2    |
# | hike messenger                                                                   | 2    |
# | Goibibo                                                                          | 2    |
# | SAP                                                                              | 2    |
# | Citi                                                                             | 2    |
# | TomTom                                                                           | 2    |
# +----------------------------------------------------------------------------------+------+

# %%
from geopy import geocoders

GEO_APP_KEY = 'AjBl_exEOrwQdY8PVGenQj89LFdjxKn2ciZKAwX-Gfn2rbESjpcwnaQyokPAwOGU' # XXX: Get this from https://www.bingmapsportal.com
g = geocoders.Bing(GEO_APP_KEY)
#print g.geocode("Nashville", exactly_one=False)

# %%
#from geopy import geocoders

#GEO_APP_KEY = 'AjBl_exEOrwQdY8PVGenQj89LFdjxKn2ciZKAwX-Gfn2rbESjpcwnaQyokPAwOGU' # XXX: Get this from https://www.bingmapsportal.com
#g = geocoders.Bing(GEO_APP_KEY)

#transforms = [('Greater ', ''), (' Area', '')]

#results = {}
#for c in connections['values']:
    #if not c.has_key('location'): continue
        
 #   transformed_location = c['location']['name']
  #  for transform in transforms:
  #      transformed_location = transformed_location.replace(*transform)
  #  geo = g.geocode(transformed_location, exactly_one=False)
  #  if geo == []: continue
  #  results.update({ c['location']['name'] : geo })
    
#print json.dumps(results, indent=1)

# %%
import re

# Most results contain a response that can be parsed by
# picking out the first two consecutive upper case letters 
# as a clue for the state
pattern = re.compile('.*([A-Z]{2}).*')
    
def parseStateFromBingResult(r):
    result = pattern.search(r[0][0])
    if result == None: 
        print "Unresolved match:", r
        return "???"
    elif len(result.groups()) == 1:
        print result.groups()
        return result.groups()[0]
    else:
        print "Unresolved match:", result.groups()
        return "???"

    
transforms = [('Greater ', ''), (' Area', '')]

results = {}
for c in connections['values']:
    if not c.has_key('location'): continue
    if not c['location']['country']['code'] == 'us': continue
        
    transformed_location = c['location']['name']
    for transform in transforms:
        transformed_location = transformed_location.replace(*transform)
    
    geo = g.geocode(transformed_location, exactly_one=False)
    if geo == []: continue
    parsed_state = parseStateFromBingResult(geo)
    if parsed_state != "???":
        results.update({c['location']['name'] : parsed_state})
    
print json.dumps(results, indent=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3d0cf99a69a2> in <module>()
#      22
#      23 results = {}
# ---> 24 for c in connections['values']:
#      25     if not c.has_key('location'): continue
#      26     if not c['location']['country']['code'] == 'us': continue
#
# NameError: name 'connections' is not defined

# %%
import os
import json
from IPython.display import IFrame
from IPython.core.display import display

# Load in a data structure mapping state names to codes.
# e.g. West Virginia is WV
codes = json.loads(open('states.json').read())

from collections import Counter
c = Counter([r[1] for r in results.items()])
states_freqs = { codes[k] : v for (k,v) in c.items() }

# Lace in all of the other states and provide a minimum value for each of them
states_freqs.update({v : 0.5 for v in codes.values() if v not in states_freqs.keys() })

# Write output to file
f = open('states_freq.json', 'w')
f.write(json.dumps(states_freqs, indent=1))
f.close()

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

display(IFrame('viz/cartogram.html', '100%', '600px'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbca58d3d557> in <module>()
#       9
#      10 from collections import Counter
# ---> 11 c = Counter([r[1] for r in results.items()])
#      12 states_freqs = { codes[k] : v for (k,v) in c.items() }
#      13
#
# NameError: name 'results' is not defined

# %%
import os
import csv
from nltk.metrics.distance import masi_distance


CSV_FILE = os.path.join('connections.csv')

DISTANCE_THRESHOLD = 0.67
DISTANCE = masi_distance

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO','Chief Technology Officer'),
        ('CFO','Chief Finance Officer'),
        ('VP',  'Vice President'),
        
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        print titles
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or clusters.has_key(title2) and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))

            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)

    # Flatten out clusters

    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]

    # Round up contacts who are in these clusters and group them together
    print '\n'
    print clusters
    print '\n'
    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts


clustered_contacts = cluster_contacts_by_title(CSV_FILE)
print clustered_contacts
for titles in clustered_contacts:
    common_titles_heading = 'Common Titles: ' + ', '.join(titles)

    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms_heading = 'Descriptive Terms: ' \
        + ', '.join(descriptive_terms)
    print descriptive_terms_heading
    print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
    print '\n'.join(clustered_contacts[titles])
    print
# Out:
# ['Student']
# ['Assistant Professor']
# ['Assistant Developer']
# ['Student']
# ['Student Ambassador']
# ['Software Developer']
# ['Head, Technical Affairs-Software']
# ['Student']
# ['Student']
# ['Student']
# ['Sofware Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Human Resources']
# ['Student']
# ['Student']
# ['Firefox Student Ambassador']
# ['Placement Coordinator']
# ['Filmmaker/Writer']
# ['Data Developer']
# ['Software Developmer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Co-founder']
# ['Assistant Manager']
# ['Software Developer']
# ['Design Secretary']
# ['Student']
# ['Telesales Executive']
# ['Management Trainee - Operations']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Developer']
# ['Oracle Database Administrator']
# ['Key Account Manager']
# ['Engineering Manager']
# ['Software Developer']
# ['Software Developer']
# ['Talent Acquisition Manager']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Student']
# ['Wireless Protocol Test Intern']
# ['Software Developer']
# ['HR Executive']
# ['Student']
# ['IT Company']
# ['Student']
# ['IT Consultant']
# ['Student']
# ['Student Ambassador']
# ['Business Development Manager']
# ['Student']
# ['Member of Technical Staff']
# ['Software Engineer']
# ['Web Designer']
# ['ECE Student']
# ['Software Developer']
# ['Intern']
# ['Intern']
# ['Head of Growth']
# ['Software Engineer']
# ['SA']
# ['Manager (Technology)']
# ['Systems Engineer']
# ['Technical Team Member']
# ['Assistant Professor']
# ['Business Developer']
# ['Software Engineer']
# ['system engineer']
# ['Software Engineer']
# ['Infrastructure Developer']
# ['Software Engineer']
# ['Engineer']
# ['Member']
# ['Software Developer']
# ['Software Engineer']
# ['Black Belt - Quality - Strategic Initiatives - Global']
# ['Firefox Student Ambassador']
# ['Student']
# ['Overall Placement Coordinator']
# ['Student']
# ['IT Consultant']
# ['IIITA Allahabad']
# ['Assistant Manager']
# ['HR - Product & Technology']
# ['Mechanical Engineer']
# ['Software Engineer']
# ['Consultant']
# ['Student Ambassador']
# ['Student']
# ['Founder & CTO']
# ['Intern']
# ['Software Developer']
# ['Student Technical Assistant']
# ['Software Developer']
# ['Data Analyst']
# ['IT Engineer']
# ['Service Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Head of Sales and Customer Engagement']
# ['Associate']
# ['Founder']
# ['Software Engineer']
# ['Software Engineer']
# ['Intern']
# ['Associate Manager, Corporate and Media Relations']
# ['Developer']
# ['Software Engineer']
# ['Intern']
# ['Student']
# ['Placement Coordinator']
# ['Member of Technical Staff ']
# ['Intern']
# ['Director - Software Engineering']
# ['Training Associate']
# ['Training and Placement Cell Co-ordinator']
# ['Internal Affairs Officer']
# ['Software developer']
# ['Developer']
# ['Research Scholar']
# ['Software Developer']
# ['Technical Team Member']
# ['Senior Director - Test Engineering']
# ['Student']
# ['Student']
# ['Senior Software Engineer']
# ['Student']
# ['Web Designer and Programmer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Professor']
# ['Software Engineer']
# ['Human Performance']
# ['Analyst']
# ['Placement Cell']
# ['Campus Recruiter']
# ['Training & Consulting in Predictive Analytics & Information Security (www.praisia.com)']
# ['Member of Technical Staff']
# ['Software Engineer']
# ['Founder']
# ['Sr. Software Engineer']
# ['Senior Trainer']
# ['Intern']
# ['Software Engineer']
# ['Assistant Manager']
# ['Programmer Analyst']
# ['Campus Ambassador']
# ['Tutor']
# ['Student and Placement Coordinator']
# ['Software Engineer']
# ['Intern']
# ['Graphic Engineer']
# ['Product Manager']
# ['Regional Marketing Ambassdor']
# ['Software Engineer']
# ['Student']
# ['System Analyst & Network Administrator']
# ['Associate Technology L1']
# ['Software Developer']
# ['Intern']
# ['Software Developer']
# ['Outreach Program for Women']
# ['Senior Software Developer']
# ['Manager']
# ['HR Recruiter']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['technical support engineer']
# ['Student']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Associate Professor']
#
#
# [['Training Associate', 'Training', 'Associate'], ['Data Analyst', 'Analyst'], ['Senior Software Engineer', 'Software Engineer'], ['Analyst', 'Programmer Analyst'], ['Graphic Engineer', 'Engineer'], ['Software Developer', 'Developer', 'Senior Software Developer'], ['Member of Technical Staff ', 'Member of Technical Staff'], ['Manager (Technology)', 'Manager'], ['Overall Placement Coordinator', 'Placement Coordinator'], ['Firefox Student Ambassador', 'Student Ambassador'], ['Data Developer', 'Developer'], ['Assistant Manager', 'Manager'], ['Placement Cell', 'Placement Cell Co-ordinator'], ['Product Manager', 'Manager'], ['Professor', 'Assistant Professor', 'Associate Professor'], ['Business Developer', 'Developer'], ['Developer', 'Assistant Developer', 'Infrastructure Developer'], ['Associate Professor', 'Associate'], ['ECE Student', 'Student'], ['IT Engineer', 'Engineer'], ['Engineering Manager', 'Manager'], ['Mechanical Engineer', 'Engineer'], ['Engineer', 'Service Engineer', 'Systems Engineer', 'Sofware Engineer', 'Software Engineer'], ['Student Ambassador', 'Student'], ['Programmer Analyst', 'Programmer'], ['System Analyst', 'Analyst'], ['Consultant', 'IT Consultant']]
#
#
# {('Engineering Manager', 'Manager'): ['Nishant Tiwari', 'Nasiruddin Ahmad'], ('System Analyst', 'Analyst'): ['Abhinav Gupta', 'Mithilesh Kr. Mishra'], ('Member of Technical Staff ', 'Member of Technical Staff'): ['Aman Sinha', 'Prakhar Agrawal', 'Abhinav Vishwa'], ('Business Developer', 'Developer'): ['srikanth br', 'Vedavyas Chigurupati', 'Suyash Agarwal'], ('Assistant Manager', 'Manager'): ['GAURAV BANSAL', 'Diwas Sharma', 'Dheeraj Singh', 'Nasiruddin Ahmad'], ('Programmer Analyst', 'Programmer'): ['JP Godara', 'Ramanan Ramesh'], ('Graphic Engineer', 'Engineer'): ['Adity Khandaalkar', 'Akshay Gupta'], ('Placement Cell', 'Placement Cell Co-ordinator'): ['Adhishwar Mittal', 'divya porwal'], ('Mechanical Engineer', 'Engineer'): ['Adity Khandaalkar', 'Sidharth Guglani'], ('Consultant', 'IT Consultant'): ['Pradeep Mishra', 'raja agarwal', 'ASHISH KUMAR SAHU'], ('Data Analyst', 'Analyst'): ['anuraag deekonda', 'Abhinav Gupta'], ('Professor', 'Assistant Professor', 'Associate Professor'): ['Monark Bag', 'sanjai singh', 'Samudrala Kumar', 'Jag Rawat'], ('Engineer', 'Service Engineer', 'Systems Engineer', 'Sofware Engineer', 'Software Engineer'): ['koganti rakesh', 'Aviral Sahai', 'sarthak mall', 'Udit Agarwal', 'deepak irukula', 'Sunil Kumar', 'Tejaswi Reddy', 'Rahul Sharma', 'Harsh Lalwani', 'Sapan Diwakar', 'Mayank Tuteja', 'Sandeep Goyal', 'Ankit Paharia', 'Prateek Khandelwal', 'Ankit Gupta', 'shailesh kumar', 'Rohit Wadhwa', 'Ajit Abhipallav', 'Dinesh Pathak', 'Arpit Mittal', 'Adity Khandaalkar', 'Krishna Murthy P.V.N.S.S', 'Aman Mamgain', 'praveen kumar', 'Mragank Tolwani', 'sumit gaur', 'Lalit Pathak', 'Shubham Jain', 'Mayank Gupta', 'Avinash Kumar Chaudhary', 'Navneet Sinha', 'manish aswani', 'Naveen Shukla', 'Sharath Naik', 'Chandresh Bhardwaj', 'Vamsi Krishna', 'Digvijay Singh', 'Amit Meena', 'Jayendra Singh', 'Keshav Maheshwari', 'vidyashankar sahu', 'Gaurav Kaushik', 'Mohit Bansal', 'Amrit Jangid', 'Naveen Chalasani'], ('Associate Professor', 'Associate'): ['nipun lall', 'Jag Rawat'], ('Analyst', 'Programmer Analyst'): ['Abhinav Gupta', 'Ramanan Ramesh'], ('Training Associate', 'Training', 'Associate'): ['nipun lall', 'Siri Jakka', 'Adhishwar Mittal', 'Praisia Technologies'], ('Software Developer', 'Developer', 'Senior Software Developer'): ['Sushil Kumar', 'seshank koganti', 'Viswash Pratap Singh', 'Ruben Roy', 'Naveen Bandlamoodi', 'Anoop Mishra', 'Pritam Kumar', 'Amar deep gupta', 'Hemant Pawar', 'Abhishek Jha', 'akshay khare', 'Vinay Kumar', 'Abhishek Kumar', 'Aman Agarwal', 'Vedavyas Chigurupati', 'Suyash Agarwal', 'Aman Singh', 'Saurabh Singh', 'Mohit Kumar Lal', 'Ashish Sinha'], ('Product Manager', 'Manager'): ['shaloo singh', 'Nasiruddin Ahmad'], ('Developer', 'Assistant Developer', 'Infrastructure Developer'): ['Lakshya Goel', 'smit hinsu', 'Vedavyas Chigurupati', 'Suyash Agarwal'], ('Manager (Technology)', 'Manager'): ['Vijay Mendiratta', 'Nasiruddin Ahmad'], ('Student Ambassador', 'Student'): ['Manu Saxena', 'Abhimanyu Singh', 'Harshit Gupta', 'Monica Singh', 'ravinder naik azmeera', 'Jyoti Singh', 'Vishal Srivastava', 'Aman Agarwal', 'Jai Mishra', 'Upendra gupta', 'Shivlal Dhundhwal', 'Amarnath kumar', 'Nishtha Rai', 'Vikhyat Tandon', 'Shubham Tyagi', 'siyaram malav', 'manish kumar', 'Vishnu Ks', 'Sumit Kumar', 'Shailendra Pratap Singh', 'Ashutosh Gupta', 'Ravi Kiran JP', 'Deepak kumhar', 'GAURAV VERMA', 'Rishabh Chandel', 'Navaz Mannan', 'Sidharth Singla', 'Talha Khan', 'ANUJ SHARMA', 'Ashok Danga', 'Pramiti Goel', 'Namrata singh chauhan', 'Aaquib Khwaja', 'Shreya Singh', 'Pretty Meena', 'Shiv Shankar Verma', 'amanraj varshney', 'Aman Aggarwal', 'Divanshu Garg'], ('Senior Software Engineer', 'Software Engineer'): ['Aviral Sahai', 'sarthak mall', 'Udit Agarwal', 'deepak irukula', 'Sunil Kumar', 'Tejaswi Reddy', 'Rahul Sharma', 'Harsh Lalwani', 'Sapan Diwakar', 'Mayank Tuteja', 'Sandeep Goyal', 'Ankit Paharia', 'Prateek Khandelwal', 'Ankit Gupta', 'shailesh kumar', 'Ajit Abhipallav', 'Dinesh Pathak', 'Arpit Mit ...
# Descriptive Terms: Manager
# -------------------------------------------
# Nishant Tiwari
# Nasiruddin Ahmad
#
# Descriptive Terms: Analyst
# --------------------------------------
# Abhinav Gupta
# Mithilesh Kr. Mishra
#
# Descriptive Terms: Member, of, Technical, Staff
# --------------------------------------------------------------------
# Aman Sinha
# Prakhar Agrawal
# Abhinav Vishwa
#
# Descriptive Terms: Developer
# --------------------------------------------
# srikanth br
# Vedavyas Chigurupati
# Suyash Agarwal
#
# Descriptive Terms: Manager
# -----------------------------------------
# GAURAV BANSAL
# Diwas Sharma
# Dheeraj Singh
# Nasiruddin Ahmad
#
# Descriptive Terms: Programmer
# ---------------------------------------------
# JP Godara
# Ramanan Ramesh
#
# Descriptive Terms: Engineer
# -----------------------------------------
# Adity Khandaalkar
# Akshay Gupta
#
# Descriptive Terms: Cell, Placement
# ----------------------------------------------------------
# Adhishwar Mittal
# divya porwal
#
# Descriptive Terms: Engineer
# --------------------------------------------
# Adity Khandaalkar
# Sidharth Guglani
#
# Descriptive Terms: Consultant
# ----------------------------------------
# Pradeep Mishra
# raja agarwal
# ASHISH KUMAR SAHU
#
# Descriptive Terms: Analyst
# ------------------------------------
# anuraag deekonda
# Abhinav Gupta
#
# Descriptive Terms: Professor
# ------------------------------------------------------------------
# Monark Bag
# sanjai singh
# Samudrala Kumar
# Jag Rawat
#
# Descriptive Terms: Engineer
# ------------------------------------------------------------------------------------------------
# koganti rakesh
# Aviral Sahai
# sarthak mall
# Udit Agarwal
# deepak irukula
# Sunil Kumar
# Tejaswi Reddy
# Rahul Sharma
# Harsh Lalwani
# Sapan Diwakar
# Mayank Tuteja
# Sandeep Goyal
# Ankit Paharia
# Prateek Khandelwal
# Ankit Gupta
# shailesh kumar
# Rohit Wadhwa
# Ajit Abhipallav
# Dinesh Pathak
# Arpit Mittal
# Adity Khandaalkar
# Krishna Murthy P.V.N.S.S
# Aman Mamgain
# praveen kumar
# Mragank Tolwani
# sumit gaur
# Lalit Pathak
# Shubham Jain
# Mayank Gupta
# Avinash Kumar Chaudhary
# Navneet Sinha
# manish aswani
# Naveen Shukla
# Sharath Naik
# Chandresh Bhardwaj
# Vamsi Krishna
# Digvijay Singh
# Amit Meena
# Jayendra Singh
# Keshav Maheshwari
# vidyashankar sahu
# Gaurav Kaushik
# Mohit Bansal
# Amrit Jangid
# Naveen Chalasani
#
# Descriptive Terms: Associate
# ---------------------------------------------
# nipun lall
# Jag Rawat
#
# Descriptive Terms: Analyst
# ------------------------------------------
# Abhinav Gupta
# Ramanan Ramesh
#
# Descriptive Terms:
# ------------------------------------------------------
# nipun lall
# Siri Jakka
# Adhishwar Mittal
# Praisia Technologies
#
# Descriptive Terms: Developer
# -----------------------------------------------------------------------
# Sushil Kumar
# seshank koganti
# Viswash Pratap Singh
# Ruben Roy
# Naveen Bandlamoodi
# Anoop Mishra
# Pritam Kumar
# Amar deep gupta
# Hemant Pawar
# Abhishek Jha
# akshay khare
# Vinay Kumar
# Abhishek Kumar
# Aman Agarwal
# Vedavyas Chigurupati
# Suyash Agarwal
# Aman Singh
# Saurabh Singh
# Mohit Kumar Lal
# Ashish Sinha
#
# Descriptive Terms: Manager
# ---------------------------------------
# shaloo singh
# Nasiruddin Ahmad
#
# Descriptive Terms: Developer
# -----------------------------------------------------------------------
# Lakshya Goel
# smit hinsu
# Vedavyas Chigurupati
# Suyash Agarwal
#
# Descriptive Terms: Manager
# --------------------------------------------
# Vijay Mendiratta
# Nasiruddin Ahmad
#
# Descriptive Terms: Student
# ------------------------------------------
# Manu Saxena
# Abhimanyu Singh
# Harshit Gupta
# Monica Singh
# ravinder naik azmeera
# Jyoti Singh
# Vishal Srivastava
# Aman Agarwal
# Jai Mishra
# Upendra gupta
# Shivlal Dhundhwal
# Amarnath kumar
# Nishtha Rai
# Vikhyat Tandon
# Shubham Tyagi
# siyaram malav
# manish kumar
# Vishnu Ks
# Sumit Kumar
# Shailendra Pratap Singh
# Ashutosh Gupta
# Ravi Kiran JP
# Deepak kumhar
# GAURAV VERMA
# Rishabh Chandel
# Navaz Mannan
# Sidharth Singla
# Talha Khan
# ANUJ SHARMA
# Ashok Danga
# Pramiti Goel
# Namrata singh chauhan
# Aaquib Khwaja
# Shreya Singh
# Pretty Meena
# Shiv Shankar Verma
# amanraj varshney
# Aman Aggarwal
# Divanshu Garg
#
# Descriptive Terms: Software, Engineer
# ----------------------------------------------------------
# Aviral Sahai
# sarthak mall
# Udit Agarwal
# deepak irukula
# Sunil Kumar
# Tejaswi Reddy
# Rahul Sharma
# Harsh Lalwani
# Sapan Diwakar
# Mayank Tuteja
# Sandeep Goyal
# Ankit Paharia
# Prateek Khandelwal
# Ankit Gupta
# shailesh kumar
# Ajit Abhipallav
# Dinesh Pathak
# Arpit Mittal
# Krishna Murthy P.V.N.S.S
# Aman Mamgain
# Mragank Tolwani
# sumit gaur
# Lalit Pathak
# Shubham Jain
# Mayank Gupta
# Akhil Yadav
# Avinash Kumar Chaudhary
# Navneet Sinha
# manish aswani
# Naveen Shukla
# Sharath Naik
# Chandresh Bhardwaj
# Vamsi Krishna
# Digvijay Singh
# Amit Meena
# Jayendra Singh
# Monika Agrawal
# Keshav Maheshwari
# vidyashankar sahu
# Gaurav Kaushik
# Mohit Bansal
# Amrit Jangid
# Naveen Chalasani
#
# Descriptive Terms: Student
# -----------------------------------
# Manu Saxena
# Abhimanyu Singh
# Monica Singh
# ravinder naik azmeera
# Jyoti Singh
# Vishal Srivastava
# Aman Agarwal
# Jai Mishra
# Upendra gupta
# Shivlal Dhundhwal
# Amarnath kumar
# Nishtha Rai
# Vikhyat Tandon
# Shubham Tyagi
# siyaram malav
# manish kumar
# Sumit Kumar
# Amit Kumar Singh
# Shailendra Pratap Singh
# Ashutosh Gupta
# Deepak kumhar
# GAURAV VERMA
# Rishabh Chandel
# Navaz Mannan
# Sidharth Singla
# Talha Khan
# ANUJ SHARMA
# Ashok Danga
# Pramiti Goel
# Namrata singh chauhan
# Aaquib Khwaja
# Shreya Singh
# Pretty Meena
# Shiv Shankar Verma
# amanraj varshney
# Aman Aggarwal
# Divanshu Garg
#
# Descriptive Terms: Developer
# ----------------------------------------
# Prabhat Kumar
# Vedavyas Chigurupati
# Suyash Agarwal
#
# Descriptive Terms: Engineer
# ------------------------------------
# Adity Khandaalkar
# Sumit Kumar Satnalika
#
# Descriptive Terms: Coordinator, Placement
# -------------------------------------------------------------------
# Vijendra Singh Aswal
# Placement Office IIIT Allahabad
# Shubham Kesarwani
# Aaquib Khwaja
#
# Descriptive Terms: Ambassador, Student
# -------------------------------------------------------------
# Harshit Gupta
# Charul Agrawal
# Vishnu Ks
# Sunil Rana
# Ravi Kiran JP

# %%
import json
import os
from IPython.display import IFrame
from IPython.core.display import display

data = {"label" : "name", "temp_items" : {}, "items" : []} 
for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if data['temp_items'].has_key(descriptive_terms):
        data['temp_items'][descriptive_terms].extend([{'name' : cc } for cc 
            in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name' : cc } for cc 
            in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name" : "%s (%s)" % (descriptive_terms, 
        len(data['temp_items'][descriptive_terms]),),
                              "children" : [i for i in 
                              data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

TEMPLATE = 'viz/dojo_tree.html.template'                                                
OUT = 'viz/dojo_tree.html'

viz_file = 'viz/dojo_tree.html'

t = open(TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4))
f.close()

# IPython Notebook can serve files and display them into
# inline frames. Prepend the path with the 'files' prefix

display(IFrame(viz_file, '400px', '600px'))
# Out:
#         <iframe
#             width="400px"
#             height=600px"
#             src="viz/dojo_tree.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import os
import csv
import random
import json
from nltk.metrics.distance import jaccard_distance
from cluster import HierarchicalClustering
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

CSV_FILE = os.path.join('connections.csv')

OUT_FILE = 'viz/d3-data.json'


DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance


SAMPLE_SIZE = 500

def cluster_contacts_by_title(csv_file):

    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr', 'Junior'),
        ('CEO', 'Chief Executive Officer'),
        ('COO', 'Chief Operating Officer'),
        ('CTO', 'Chief Technology Officer'),
        ('CFO', 'Chief Finance Officer'),
        ('VP', 'Vice President'),
        ]

    separators = ['/', 'and', '&']

    csvReader = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    all_titles = []
    for i, _ in enumerate(contacts):
        if contacts[i]['Job Title'] == '':
            contacts[i]['Job Titles'] = ['']
            continue
        titles = [contacts[i]['Job Title']]
        for title in titles:
            for separator in separators:
                if title.find(separator) >= 0:
                    titles.remove(title)
                    titles.extend([title.strip() for title in title.split(separator)
                                  if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Job Titles'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))

    # Feed the class your data and the scoring function
    hc = HierarchicalClustering(all_titles, score)
    set_linkage_method('single')
    # Cluster the data according to a distance threshold
    clusters = hc.getlevel(DISTANCE_THRESHOLD)

    # Remove singleton clusters
    clusters = [c for c in clusters if len(c) > 1]

    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Job Titles']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s'
                            % (contact['First Name'], contact['Last Name']))

    return clustered_contacts

def display_output(clustered_contacts):
    
    for titles in clustered_contacts:
        common_titles_heading = 'Common Titles: ' + ', '.join(titles)

        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
            + ', '.join(descriptive_terms)
        print descriptive_terms_heading
        print '-' * max(len(descriptive_terms_heading), len(common_titles_heading))
        print '\n'.join(clustered_contacts[titles])
        print

def write_d3_json_output(clustered_contacts):
    
    json_output = {'name' : 'My LinkedIn', 'children' : []}

    for titles in clustered_contacts:

        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))

        json_output['children'].append({'name' : ', '.join(descriptive_terms)[:30], 
                                    'children' : [ {'name' : c.decode('utf-8', 'replace')} for c in clustered_contacts[titles] ] } )
    
        f = open(OUT_FILE, 'w')
        f.write(json.dumps(json_output, indent=1))
        f.close()
    
clustered_contacts = cluster_contacts_by_title(CSV_FILE)
display_output(clustered_contacts)
write_d3_json_output(clustered_contacts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-773ef790bb8d> in <module>()
#     116         f.close()
#     117
# --> 118 clustered_contacts = cluster_contacts_by_title(CSV_FILE)
#     119 display_output(clustered_contacts)
#     120 write_d3_json_output(clustered_contacts)
#
# <ipython-input-3-773ef790bb8d> in cluster_contacts_by_title(csv_file)
#      65     # Feed the class your data and the scoring function
#      66     hc = HierarchicalClustering(all_titles, score)
# ---> 67     set_linkage_method('single')
#      68     # Cluster the data according to a distance threshold
#      69     clusters = hc.getlevel(DISTANCE_THRESHOLD)
#
# NameError: global name 'set_linkage_method' is not defined

# %%
import os
from IPython.display import IFrame
from IPython.core.display import display

viz_file = 'viz/node_link_tree.html'

display(IFrame(viz_file, '100%', '600px'))
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="viz/node_link_tree.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import os
import csv
import random
import json
import operator
from nltk.metrics.distance import jaccard_distance
from cluster import HierarchicalClustering

CSV_FILE = os.path.join('connections.csv')

OUT_FILE = 'viz/d3-data.json'


DISTANCE_THRESHOLD = 0.5
DISTANCE = jaccard_distance


SAMPLE_SIZE = 500
def cluster_contacts_by_title(csv_file):


    transforms = [
        ('Sr.', 'Senior'),
        ('Sr', 'Senior'),
        ('Jr.', 'Junior'),
        ('Jr','Junior'),
        ('CEO','Chief Executive Officer'),
        ('COO','Chief Operating Officer'),
        ('CTO','Chief Technology Officer'),
        ('CFO','Chief Finance Officer'),
        ('VP','Vice President'),
        
        ]

    tokenize_along = ['/','&','and']

    csvread = csv.DictReader(open(csv_file), delimiter=',', quotechar='"')
    connection = [row for row in csvread]
    titles=[]
   # print connection
    for i, _ in enumerate(connection):
        if connection[i]['Job Title'] == '':
            connection[i]['Job Titles'] = ['']
            continue
        indiv_title=[connection[i]['Job Title']]
#  print indiv_title
        for t in indiv_title:
            
            for seperator in tokenize_along:
                
                if t.find(seperator) >= 0:

                    indiv_title.remove(t)
                    t=t.strip()
                    temp=[]
                    if t!= '':
                        for title in t.split(seperator):
                            temp.append(title)

                        indiv_title.extend(temp)
        print indiv_title
        for transform in transforms:
            indiv_title = [title.replace(*transform) for title in indiv_title]
        connection[i]['Job Titles'] = indiv_title
        titles.extend(indiv_title)
#   print titles
    titles=list(set(titles))
    print titles

    
    
    # Define a scoring function
    def score(title1, title2): 
        return DISTANCE(set(title1.split()), set(title2.split()))





clustered_contacts = cluster_contacts_by_title(CSV_FILE)
#display_output(clustered_contacts)
#write_d3_json_output(clustered_contacts)
# Out:
# ['Student']
# ['Assistant Professor']
# ['Assistant Developer']
# ['Student']
# ['Student Ambassador']
# ['Software Developer']
# ['Head, Technical Affairs-Software']
# ['Student']
# ['Student']
# ['Student']
# ['Sofware Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Engineer']
# ['Human Resources']
# ['Student']
# ['Student']
# ['Firefox Student Ambassador']
# ['Placement Coordinator']
# ['Filmmaker', 'Writer']
# ['Data Developer']
# ['Software Developmer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Co-founder']
# ['Assistant Manager']
# ['Software Developer']
# ['Design Secretary']
# ['Student']
# ['Telesales Executive']
# ['Management Trainee - Operations']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Software Developer']
# ['Oracle Database Administrator']
# ['Key Account Manager']
# ['Engineering Manager']
# ['Software Developer']
# ['Software Developer']
# ['Talent Acquisition Manager']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Student']
# ['Wireless Protocol Test Intern']
# ['Software Developer']
# ['HR Executive']
# ['Student']
# ['IT Company']
# ['Student']
# ['IT Consultant']
# ['Student']
# ['Student Ambassador']
# ['Business Development Manager']
# ['Student']
# ['Member of Technical Staff']
# ['Software Engineer']
# ['Web Designer']
# ['ECE Student']
# ['Software Developer']
# ['Intern']
# ['Intern']
# ['Head of Growth']
# ['Software Engineer']
# ['SA']
# ['Manager (Technology)']
# ['Systems Engineer']
# ['Technical Team Member']
# ['Assistant Professor']
# ['Business Developer']
# ['Software Engineer']
# ['system engineer']
# ['Software Engineer']
# ['Infrastructure Developer']
# ['Software Engineer']
# ['Engineer']
# ['Member']
# ['Software Developer']
# ['Software Engineer']
# ['Black Belt - Quality - Strategic Initiatives - Global']
# ['Firefox Student Ambassador']
# ['Student']
# ['Overall Placement Coordinator']
# ['Student']
# ['IT Consultant']
# ['IIITA Allahabad']
# ['Assistant Manager']
# ['HR - Product ', ' Technology']
# ['Mechanical Engineer']
# ['Software Engineer']
# ['Consultant']
# ['Student Ambassador']
# ['Student']
# ['Founder ', ' CTO']
# ['Intern']
# ['Software Developer']
# ['Student Technical Assistant']
# ['Software Developer']
# ['Data Analyst']
# ['IT Engineer']
# ['Service Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Software Developer']
# ['Software Engineer']
# ['Head of Sales ', ' Customer Engagement']
# ['Associate']
# ['Founder']
# ['Software Engineer']
# ['Software Engineer']
# ['Intern']
# ['Associate Manager, Corporate ', ' Media Relations']
# ['Developer']
# ['Software Engineer']
# ['Intern']
# ['Student']
# ['Placement Coordinator']
# ['Member of Technical Staff ']
# ['Intern']
# ['Director - Software Engineering']
# ['Training Associate']
# ['Training ', ' Placement Cell Co-ordinator']
# ['Internal Affairs Officer']
# ['Software developer']
# ['Developer']
# ['Research Scholar']
# ['Software Developer']
# ['Technical Team Member']
# ['Senior Director - Test Engineering']
# ['Student']
# ['Student']
# ['Senior Software Engineer']
# ['Student']
# ['Web Designer ', ' Programmer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['Student']
# ['Software Engineer']
# ['Professor']
# ['Software Engineer']
# ['Human Performance']
# ['Analyst']
# ['Placement Cell']
# ['Campus Recruiter']
# ['Training ', ' Consulting in Predictive Analytics ', ' Information Security (www.praisia.com)']
# ['Member of Technical Staff']
# ['Software Engineer']
# ['Founder']
# ['Sr. Software Engineer']
# ['Senior Trainer']
# ['Intern']
# ['Software Engineer']
# ['Assistant Manager']
# ['Programmer Analyst']
# ['Campus Ambassador']
# ['Tutor']
# ['Student ', ' Placement Coordinator']
# ['Software Engineer']
# ['Intern']
# ['Graphic Engineer']
# ['Product Manager']
# ['Regional Marketing Ambassdor']
# ['Software Engineer']
# ['Student']
# ['System Analyst ', ' Network Administrator']
# ['Associate Technology L1']
# ['Software Developer']
# ['Intern']
# ['Software Developer']
# ['Outreach Program for Women']
# ['Senior Software Developer']
# ['Manager']
# ['HR Recruiter']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Software Engineer']
# ['technical support engineer']
# ['Student']
# ['Student']
# ['Student']
# ['Software Engineer']
# ['Associate Professor']
# ['Key Account Manager', 'IIITA Allahabad', 'Product Manager', 'Human Resources', 'Training Associate', 'technical support engineer', 'Business Development Manager', 'Head of Sales ', 'Student Technical Assistant', ' Chief Technology Officer', 'Member of Technical Staff', 'HR Executive', 'Data Analyst', 'Filmmaker', 'Software developer', 'Senior Software Engineer', 'Web Designer', 'Graphic Engineer', 'Software Developer', 'Black Belt - Quality - Strategic Initiatives - Global', ' Technology', 'Member', 'Associate Technology L1', 'Member of Technical Staff ', 'Director - Software Engineering', 'Manager (Technology)', 'HR - Product ', 'Head, Technical Affairs-Software', 'Campus Recruiter', 'Overall Placement Coordinator', 'Firefox Student Ambassador', 'Data Developer', 'Assistant Manager', 'Placement Cell', 'Management Trainee - Operations', 'Training ', 'Wireless Protocol Test Intern', 'Professor', 'Founder ', 'Associate Manager, Corporate ', ' Consulting in Predictive Analytics ', ' Media Relations', ' Customer Engagement', 'Business Developer', 'Student ', 'Senior Trainer', 'Founder', ' Placement Coordinator', 'Web Designer ', 'Developer', 'Human Performance', 'Head of Growth', 'Assistant Professor', 'Tutor', ' Network Administrator', ' Information Security (www.praisia.com)', 'Assistant Developer', ' Placement Cell Co-ordinator', 'Internal Affairs Officer', 'Associate Professor', 'Design Secretary', 'Technical Team Member', 'ECE Student', 'Telesales Executive', 'Infrastructure Developer', 'Placement Coordinator', ' Programmer', 'IT Engineer', 'Analyst', 'Engineering Manager', 'Campus Ambassador', 'Talent Acquisition Manager', 'SA', 'Mechanical Engineer', 'System Analyst ', 'Co-founder', 'Engineer', 'HR Recruiter', 'Research Scholar', 'Writer', 'Software Developmer', 'Service Engineer', 'Student Ambassador', 'Associate', 'Manager', 'Oracle Database Administrator', 'Student', 'Programmer Analyst', 'Systems Engineer', 'Senior Software Developer', 'IT Company', 'Consultant', 'Regional Marketing Ambassdor', 'IT Consultant', 'Senior Director - Test Engineering', 'Sofware Engineer', 'Outreach Program for Women', 'Intern', 'system engineer', 'Software Engineer']
